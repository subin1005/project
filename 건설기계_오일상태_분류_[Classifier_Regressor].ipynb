# %% [markdown]
# <a href="https://colab.research.google.com/github/subin1005/project/blob/main/%EA%B1%B4%EC%84%A4%EA%B8%B0%EA%B3%84_%EC%98%A4%EC%9D%BC%EC%83%81%ED%83%9C_%EB%B6%84%EB%A5%98_%5BClassifier_Regressor%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 건설기계 오일상태 분류 경진대회

# %% [markdown]
# ### 0. 대회설명

# %% [markdown]
#  - **대회명** : 건설기계 오일 상태 분류 AI 경진대회
#  - **대회주제** : 건설장비에서 작동오일의 상태 판단 모델개발 (정상, 이상의 이진분류)
#  - **분석 아이디어** : 지식 증류(Knowledge Distillation) 기법을 통한 모델 학습
#
# **지식 증류 (Knowledge Distillation)** : 이미 학습된 모델(교사모델)을 이용하여
# 학습이 부족한 모델(학생모델)을 학습시키는 방법으로 이번 분석에서 train이 가진 정보가 test의 정보보다 많아서, (= train 변수 개수 > test 변수 개수)  train의 전체 변수로 먼저 모델을 학습한 뒤에, 그 모델을 이용하여 test에 속하는 변수들만을 가지고 학습하는 방법이다.

# %% [markdown]
# ### 1. 라이브러리 불러오기

# %%
import torch
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import os
import pandas as pd
import numpy as np
import random
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 2. 데이터 불러오기

# %%
# 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 데이터 불러오기
train = pd.read_csv('/content/drive/MyDrive/건설기계 오일 상태 분류 경진대회/train.csv')
test = pd.read_csv('/content/drive/MyDrive/건설기계 오일 상태 분류 경진대회/test.csv')

# %% [markdown]
# - Fixed RandomSeed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(0)

# %% [markdown]
# ### 3. 데이터 탐색 및 전처리

# %% [markdown]
# - 데이터 형태확인

# %%
train.head()
# Out:
#             ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  SAMPLE_TRANSFER_DAY  \
# 0  TRAIN_00000          COMPONENT3         1486  2011                    7
# 1  TRAIN_00001          COMPONENT2         1350  2021                   51
# 2  TRAIN_00002          COMPONENT2         2415  2015                    2
# 3  TRAIN_00003          COMPONENT3         7389  2010                    2
# 4  TRAIN_00004          COMPONENT3         3954  2015                    4
#
#    ANONYMOUS_2  AG   AL    B  BA  ...  U25  U20   U14       U6       U4  V  \
# 0          200   0    3   93   0  ...  NaN  NaN   NaN      NaN      NaN  0
# 1          375   0    2   19   0  ...  2.0  4.0   6.0    216.0   1454.0  0
# 2          200   0  110    1   1  ...  0.0  3.0  39.0  11261.0  41081.0  0
# 3          200   0    8    3   0  ...  NaN  NaN   NaN      NaN      NaN  0
# 4          200   0    1  157   0  ...  NaN  NaN   NaN      NaN      NaN  0
#
#    V100    V40   ZN  Y_LABEL
# 0   NaN  154.0   75        0
# 1   NaN   44.0  652        0
# 2   NaN   72.6  412        1
# 3   NaN  133.3    7        0
# 4   NaN  133.1  128        0
#
# [5 rows x 54 columns]

# %%
test.head()
# Out:
#           ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  ANONYMOUS_2  AG  CO  CR  \
# 0  TEST_0000          COMPONENT1         2192  2016          200   0   0   0
# 1  TEST_0001          COMPONENT3         2794  2011          200   0   0   2
# 2  TEST_0002          COMPONENT2         1982  2010          200   0   0   0
# 3  TEST_0003          COMPONENT3         1404  2009          200   0   0   3
# 4  TEST_0004          COMPONENT2         8225  2013          200   0   0   0
#
#    CU   FE  H2O  MN  MO  NI  PQINDEX  TI  V    V40    ZN
# 0   1   12  0.0   0   0   0       10   0  0   91.3  1091
# 1   1  278  0.0   3   0   0     2732   1  0  126.9    12
# 2  16    5  0.0   0   0   0       11   0  0   44.3   714
# 3   4  163  0.0   4   3   0     8007   0  0  142.8    94
# 4   6   13  0.0   0   0   0       16   0  0   63.4   469

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14095 entries, 0 to 14094
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   14095 non-null  object
#  1   COMPONENT_ARBITRARY  14095 non-null  object
#  2   ANONYMOUS_1          14095 non-null  int64
#  3   YEAR                 14095 non-null  int64
#  4   SAMPLE_TRANSFER_DAY  14095 non-null  int64
#  5   ANONYMOUS_2          14095 non-null  int64
#  6   AG                   14095 non-null  int64
#  7   AL                   14095 non-null  int64
#  8   B                    14095 non-null  int64
#  9   BA                   14095 non-null  int64
#  10  BE                   14095 non-null  int64
#  11  CA                   14095 non-null  int64
#  12  CD                   12701 non-null  float64
#  13  CO                   14095 non-null  int64
#  14  CR                   14095 non-null  int64
#  15  CU                   14095 non-null  int64
#  16  FH2O                 3890 non-null   float64
#  17  FNOX                 3890 non-null   float64
#  18  FOPTIMETHGLY         3890 non-null   float64
#  19  FOXID                3890 non-null   float64
#  20  FSO4                 3890 non-null   float64
#  21  FTBN                 3890 non-null   float64
#  22  FE                   14095 non-null  int64
#  23  FUEL                 3890 non-null   float64
#  24  H2O                  14095 non-null  float64
#  25  K                    11796 non-null  float64
#  26  LI                   14095 non-null  int64
#  27  MG                   14095 non-null  int64
#  28  MN                   14095 non-null  int64
#  29  MO                   14095 non-null  int64
#  30  NA                   14095 non-null  int64
#  31  NI                   14095 non-null  int64
#  32  P                    14095 non-null  int64
#  33  PB                   14095 non-null  int64
#  34  PQINDEX              14095 non-null  int64
#  35  S                    14095 non-null  int64
#  36  SB                   14095 non-null  int64
#  37  SI                   14095 non-null  int64
#  38  SN                   14095 non-null  int64
#  39  SOOTPERCENTAGE       3890 non-null   float64
#  40  TI                   14095 non-null  int64
#  41  U100                 2316 non-null   float64
#  42  U75                  2316 non-null   float64
#  43  U50                  2316 non-null   float64
#  44  U25                  2316 non-null   float64
#  45  U20                  2316 non-null   float64
#  46  U14                  2118 non-null   float64
#  47  U6                   2118 non-null   float64
#  48  U4                   2118 non-null   float64
#  49  V                    14095 non-null  int64
#  50  V100                 3724 non-null   float64
#  51  V40                  14095 non-null  float64
#  52  ZN                   14095 non-null  int64
#  53  Y_LABEL              14095 non-null  int64
# dtypes: float64(21), int64(31), object(2)
# memory usage: 5.8+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6041 entries, 0 to 6040
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   6041 non-null   object
#  1   COMPONENT_ARBITRARY  6041 non-null   object
#  2   ANONYMOUS_1          6041 non-null   int64
#  3   YEAR                 6041 non-null   int64
#  4   ANONYMOUS_2          6041 non-null   int64
#  5   AG                   6041 non-null   int64
#  6   CO                   6041 non-null   int64
#  7   CR                   6041 non-null   int64
#  8   CU                   6041 non-null   int64
#  9   FE                   6041 non-null   int64
#  10  H2O                  6041 non-null   float64
#  11  MN                   6041 non-null   int64
#  12  MO                   6041 non-null   int64
#  13  NI                   6041 non-null   int64
#  14  PQINDEX              6041 non-null   int64
#  15  TI                   6041 non-null   int64
#  16  V                    6041 non-null   int64
#  17  V40                  6041 non-null   float64
#  18  ZN                   6041 non-null   int64
# dtypes: float64(2), int64(15), object(2)
# memory usage: 896.8+ KB

# %% [markdown]
#  1. train : 54개의 변수(범주형 변수 2개 + Y_LABEL도 범주형으로 보임), 총 14095개의 데이터
#  2. test : 19개의 변수, 총 6041개의 데이터
#
# 인덱스 역할의 `ID` 변수가 있으며, train 변수개수가 test 변수개수에 비해 35개 (타깃변수인 Y_LABEL 포함) 더 많음

# %% [markdown]
# - 결측치 확인

# %%
train.isnull().sum()/len(train)
# Out:
# ID                     0.000000
# COMPONENT_ARBITRARY    0.000000
# ANONYMOUS_1            0.000000
# YEAR                   0.000000
# SAMPLE_TRANSFER_DAY    0.000000
# ANONYMOUS_2            0.000000
# AG                     0.000000
# AL                     0.000000
# B                      0.000000
# BA                     0.000000
# BE                     0.000000
# CA                     0.000000
# CD                     0.098900
# CO                     0.000000
# CR                     0.000000
# CU                     0.000000
# FH2O                   0.724016
# FNOX                   0.724016
# FOPTIMETHGLY           0.724016
# FOXID                  0.724016
# FSO4                   0.724016
# FTBN                   0.724016
# FE                     0.000000
# FUEL                   0.724016
# H2O                    0.000000
# K                      0.163107
# LI                     0.000000
# MG                     0.000000
# MN                     0.000000
# MO                     0.000000
# NA                     0.000000
# NI                     0.000000
# P                      0.000000
# PB                     0.000000
# PQINDEX                0.000000
# S                      0.000000
# SB                     0.000000
# SI                     0.000000
# SN                     0.000000
# SOOTPERCENTAGE         0.724016
# TI                     0.000000
# U100                   0.835686
# U75                    0.835686
# U50                    0.835686
# U25                    0.835686
# U20                    0.835686
# U14                    0.849734
# U6                     0.849734
# U4                     0.849734
# V                      0.000000
# V100                   0.735793
# V40                    0.000000
# ZN                     0.000000
# Y_LABEL                0.000000
# dtype: float64

# %%
test.isnull().sum()
# Out:
# ID                     0
# COMPONENT_ARBITRARY    0
# ANONYMOUS_1            0
# YEAR                   0
# ANONYMOUS_2            0
# AG                     0
# CO                     0
# CR                     0
# CU                     0
# FE                     0
# H2O                    0
# MN                     0
# MO                     0
# NI                     0
# PQINDEX                0
# TI                     0
# V                      0
# V40                    0
# ZN                     0
# dtype: int64

# %% [markdown]
# 1. train : 전체 54개의 변수 중 17개의 변수가 70% 이상 결측이고, `K`, `CD` 변수는 20% 이하의 결측이 확인됨
# 2. test : 결측치 없음

# %% [markdown]
# ##### 결측치 처리

# %% [markdown]
# - 결측이 70% 이상인 컬럼 제거 (총 17개) : 모두 test 데이터에는 없는 변수

# %%
train = train.drop(columns = ['FH2O', 'FNOX', 'FOPTIMETHGLY', 'FOXID', 'FSO4', 'FTBN',
                              'FUEL', 'SOOTPERCENTAGE', 'U100', 'U75', 'U50', 'U25',
                              'U20', 'U14', 'U6', 'U4', 'V100'])

# %% [markdown]
# - 변수 `CD` 결측치 대치

# %%
train['CD'].describe()
# Out:
# count    12701.000000
# mean         0.015589
# std          0.209407
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         18.000000
# Name: CD, dtype: float64

# %%
len(train[train['CD']==0])/len(train)
# Out:
# 0.889890031926215

# %%
train['CD'] = train['CD'].fillna(0)

# %% [markdown]
# > `CD` 데이터를 살펴본 결과, 약 89% 데이터가 0을 가지는 것을 확인 => 결측치를 0값으로 대치

# %% [markdown]
# - 변수 `K` 결측치 대치

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors = 5)
train['K'] = imputer.fit_transform(train['K'].values.reshape(-1, 1))

# %%
train.isnull().sum()
# Out:
# ID                     0
# COMPONENT_ARBITRARY    0
# ANONYMOUS_1            0
# YEAR                   0
# SAMPLE_TRANSFER_DAY    0
# ANONYMOUS_2            0
# AG                     0
# AL                     0
# B                      0
# BA                     0
# BE                     0
# CA                     0
# CD                     0
# CO                     0
# CR                     0
# CU                     0
# FE                     0
# H2O                    0
# K                      0
# LI                     0
# MG                     0
# MN                     0
# MO                     0
# NA                     0
# NI                     0
# P                      0
# PB                     0
# PQINDEX                0
# S                      0
# SB                     0
# SI                     0
# SN                     0
# TI                     0
# V                      0
# V40                    0
# ZN                     0
# Y_LABEL                0
# dtype: int64

# %% [markdown]
# 모든 결측 데이터가 대치되어 더이상 결측치가 없음을 확인

# %% [markdown]
# ##### Y_LABEL 변수 타입 변경

# %%
train['Y_LABEL'] = train['Y_LABEL'].astype('category')

# %% [markdown]
# ##### 분석에 필요하지 않는 `ID` 변수 제거

# %%
train.drop(['ID'], axis = 1, inplace = True)
test.drop(['ID'], axis = 1, inplace = True)

# %% [markdown]
# ##### 범주형 변수와 test에만 있는 변수 저장 (타깃변수인 `Y_LABEL` 제외)

# %%
categorical_features = ['COMPONENT_ARBITRARY', 'YEAR']
test_stage_features = list(test.columns)

# %% [markdown]
# ##### 데이터 분할

# %%
X = train.drop(['Y_LABEL'], axis = 1)
y = train['Y_LABEL']
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=0.3,  stratify=y, random_state = 0)#test_size = 0.2)

# %% [markdown]
# ##### 표준화 (수치형변수)

# %%
from sklearn.preprocessing import MinMaxScaler

def get_values(value):
    return value.values.reshape(-1, 1)

for col in train_X.columns:
    if col not in categorical_features:
        scaler = MinMaxScaler()
        train_X[col] = scaler.fit_transform(get_values(train_X[col]))
        val_X[col] = scaler.transform(get_values(val_X[col]))

        if col in test.columns:
            test[col] = scaler.transform(get_values(test[col]))

# %% [markdown]
# ##### 레이블 인코딩 (범주형)

# %%
le = LabelEncoder()
for col in categorical_features:
    train_X[col] = le.fit_transform(train_X[col])
    val_X[col] = le.transform(val_X[col])
    if col in test.columns:
        test[col] = le.transform(test[col])

# %%
# train_X, val_X 변수명 부여
train_X = pd.DataFrame(train_X, columns = X.columns)
val_X = pd.DataFrame(val_X, columns = X.columns)

# %% [markdown]
# ##### 데이터 형태 확인

# %%
# Y_LABEL이 불균형 데이터임을 확인할 수 있다.
train_y.value_counts()
# Out:
# Y_LABEL
# 0    9024
# 1     842
# Name: count, dtype: int64

# %% [markdown]
# ### 4. OverSampling
#  - 데이터 불균형 문제를 완화해 주기 위해 오버샘플링 실시.

# %%
# # (1) 랜덤오버샘플링

# from imblearn.over_sampling import RandomOverSampler
# X_train_over, y_train_over = RandomOverSampler(random_state=0).fit_resample(train_X, train_y)

# %%
# (2) smote

from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_over, y_train_over = smote.fit_resample(train_X, train_y)

# %%
# # (3) borderline-SMOTE

# from imblearn.over_sampling import BorderlineSMOTE
# from collections import Counter
# oversample = BorderlineSMOTE(random_state = 0)
# X_train_over, y_train_over = oversample.fit_resample(train_X, train_y)
# counter = Counter(y_train_over)
# print(counter)

# %% [markdown]
# RandomOverSampler, SMOTE, BorderlineSMOTE 중 점수가 좋았던 SMOTE를 사용하여 오버샘플링을 진행

# %% [markdown]
# ### 5. Modeling

# %% [markdown]
# #### [1] Classifier model

# %% [markdown]
# ##### 1) Catboost

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.4.2)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5

# %%
from catboost import CatBoostClassifier, Pool
model = CatBoostClassifier(iterations=500,
                           depth=5,
                           learning_rate=0.1,
                           loss_function='Logloss',
                           verbose=True,
                           random_state = 0)
model.fit(X_train_over, y_train_over)
pred = model.predict(val_X)
# Out:
# 0:	learn: 0.5852179	total: 60.1ms	remaining: 30s
# 1:	learn: 0.5119804	total: 71.5ms	remaining: 17.8s
# 2:	learn: 0.4592224	total: 82.5ms	remaining: 13.7s
# 3:	learn: 0.4172240	total: 92.9ms	remaining: 11.5s
# 4:	learn: 0.3841836	total: 103ms	remaining: 10.2s
# 5:	learn: 0.3521945	total: 114ms	remaining: 9.41s
# 6:	learn: 0.3293910	total: 125ms	remaining: 8.83s
# 7:	learn: 0.3131558	total: 136ms	remaining: 8.37s
# 8:	learn: 0.2946358	total: 147ms	remaining: 8.02s
# 9:	learn: 0.2753902	total: 157ms	remaining: 7.71s
# 10:	learn: 0.2602894	total: 168ms	remaining: 7.46s
# 11:	learn: 0.2494542	total: 178ms	remaining: 7.26s
# 12:	learn: 0.2383208	total: 189ms	remaining: 7.08s
# 13:	learn: 0.2284004	total: 203ms	remaining: 7.06s
# 14:	learn: 0.2223367	total: 216ms	remaining: 6.97s
# 15:	learn: 0.2139972	total: 226ms	remaining: 6.84s
# 16:	learn: 0.2081899	total: 237ms	remaining: 6.74s
# 17:	learn: 0.2036264	total: 248ms	remaining: 6.64s
# 18:	learn: 0.1973996	total: 266ms	remaining: 6.74s
# 19:	learn: 0.1920820	total: 277ms	remaining: 6.64s
# 20:	learn: 0.1863176	total: 287ms	remaining: 6.55s
# 21:	learn: 0.1791553	total: 298ms	remaining: 6.47s
# 22:	learn: 0.1775130	total: 313ms	remaining: 6.5s
# 23:	learn: 0.1736535	total: 336ms	remaining: 6.66s
# 24:	learn: 0.1687848	total: 347ms	remaining: 6.59s
# 25:	learn: 0.1659833	total: 361ms	remaining: 6.58s
# 26:	learn: 0.1643645	total: 373ms	remaining: 6.54s
# 27:	learn: 0.1615613	total: 383ms	remaining: 6.46s
# 28:	learn: 0.1601097	total: 394ms	remaining: 6.39s
# 29:	learn: 0.1586787	total: 404ms	remaining: 6.33s
# 30:	learn: 0.1563052	total: 415ms	remaining: 6.28s
# 31:	learn: 0.1534109	total: 427ms	remaining: 6.25s
# 32:	learn: 0.1484675	total: 438ms	remaining: 6.2s
# 33:	learn: 0.1464805	total: 452ms	remaining: 6.2s
# 34:	learn: 0.1437219	total: 465ms	remaining: 6.18s
# 35:	learn: 0.1425215	total: 477ms	remaining: 6.14s
# 36:	learn: 0.1407445	total: 487ms	remaining: 6.09s
# 37:	learn: 0.1392720	total: 497ms	remaining: 6.05s
# 38:	learn: 0.1378154	total: 508ms	remaining: 6s
# 39:	learn: 0.1366132	total: 518ms	remaining: 5.96s
# 40:	learn: 0.1353584	total: 529ms	remaining: 5.92s
# 41:	learn: 0.1343385	total: 539ms	remaining: 5.88s
# 42:	learn: 0.1335873	total: 550ms	remaining: 5.84s
# 43:	learn: 0.1320994	total: 560ms	remaining: 5.8s
# 44:	learn: 0.1313055	total: 570ms	remaining: 5.77s
# 45:	learn: 0.1307205	total: 580ms	remaining: 5.73s
# 46:	learn: 0.1299992	total: 595ms	remaining: 5.74s
# 47:	learn: 0.1294260	total: 606ms	remaining: 5.71s
# 48:	learn: 0.1289510	total: 616ms	remaining: 5.67s
# 49:	learn: 0.1280433	total: 630ms	remaining: 5.67s
# 50:	learn: 0.1264417	total: 644ms	remaining: 5.67s
# 51:	learn: 0.1257381	total: 654ms	remaining: 5.63s
# 52:	learn: 0.1237481	total: 669ms	remaining: 5.64s
# 53:	learn: 0.1231817	total: 680ms	remaining: 5.61s
# 54:	learn: 0.1226122	total: 690ms	remaining: 5.58s
# 55:	learn: 0.1219581	total: 701ms	remaining: 5.55s
# 56:	learn: 0.1214091	total: 711ms	remaining: 5.52s
# 57:	learn: 0.1201600	total: 724ms	remaining: 5.52s
# 58:	learn: 0.1198090	total: 742ms	remaining: 5.54s
# 59:	learn: 0.1183634	total: 752ms	remaining: 5.51s
# 60:	learn: 0.1174133	total: 762ms	remaining: 5.49s
# 61:	learn: 0.1166932	total: 773ms	remaining: 5.46s
# 62:	learn: 0.1159042	total: 783ms	remaining: 5.43s
# 63:	learn: 0.1156520	total: 797ms	remaining: 5.43s
# 64:	learn: 0.1154953	total: 808ms	remaining: 5.41s
# 65:	learn: 0.1148024	total: 819ms	remaining: 5.38s
# 66:	learn: 0.1134835	total: 830ms	remaining: 5.36s
# 67:	learn: 0.1131948	total: 839ms	remaining: 5.33s
# 68:	learn: 0.1124251	total: 850ms	remaining: 5.31s
# 69:	learn: 0.1120322	total: 861ms	remaining: 5.29s
# 70:	learn: 0.1115733	total: 875ms	remaining: 5.28s
# 71:	learn: 0.1111965	total: 885ms	remaining: 5.26s
# 72:	learn: 0.1108201	total: 895ms	remaining: 5.24s
# 73:	learn: 0.1093131	total: 906ms	remaining: 5.21s
# 74:	learn: 0.1090123	total: 916ms	remaining: 5.19s
# 75:	learn: 0.1087260	total: 926ms	remaining: 5.17s
# 76:	learn: 0.1081225	total: 937ms	remaining: 5.14s
# 77:	learn: 0.1077536	total: 947ms	remaining: 5.12s
# 78:	learn: 0.1072857	total: 957ms	remaining: 5.1s
# 79:	learn: 0.1068265	total: 967ms	remaining: 5.08s
# 80:	learn: 0.1065859	total: 977ms	remaining: 5.05s
# 81:	learn: 0.1063974	total: 987ms	remaining: 5.03s
# 82:	learn: 0.1060823	total: 998ms	remaining: 5.01s
# 83:	learn: 0.1056538	total: 1.01s	remaining: 4.99s
# 84:	learn: 0.1052536	total: 1.02s	remaining: 4.97s
# 85:	learn: 0.1049600	total: 1.03s	remaining: 4.95s
# 86:	learn: 0.1046142	total: 1.04s	remaining: 4.93s
# 87:	learn: 0.1043388	total: 1.05s	remaining: 4.91s
# 88:	learn: 0.1040736	total: 1.06s	remaining: 4.89s
# 89:	learn: 0.1037385	total: 1.07s	remaining: 4.87s
# 90:	learn: 0.1032888	total: 1.08s	remaining: 4.87s
# 91:	learn: 0.1030008	total: 1.09s	remaining: 4.86s
# 92:	learn: 0.1026162	total: 1.1s	remaining: 4.84s
# 93:	learn: 0.1022423	total: 1.11s	remaining: 4.82s
# 94:	learn: 0.1019023	total: 1.12s	remaining: 4.79s
# 95:	learn: 0.1009081	total: 1.14s	remaining: 4.79s
# 96:	learn: 0.1005582	total: 1.15s	remaining: 4.76s
# 97:	learn: 0.0992158	total: 1.16s	remaining: 4.75s
# 98:	learn: 0.0989820	total: 1.17s	remaining: 4.73s
# 99:	learn: 0.0985728	total: 1.18s	remaining: 4.71s
# 100:	learn: 0.0981656	total: 1.19s	remaining: 4.69s
# 101:	learn: 0.0974889	total: 1.2s	remaining: 4.69s
# 102:	learn: 0.0972505	total: 1.21s	remaining: 4.67s
# 103:	learn: 0.0968959	total: 1.22s	remaining: 4.65s
# 104:	learn: 0.0965617	total: 1.23s	remaining: 4.63s
# 105:	learn: 0.0958806	total: 1.24s	remaining: 4.62s
# 106:	learn: 0.0956917	total: 1.25s	remaining: 4.61s
# 107:	learn: 0.0954707	total: 1.26s	remaining: 4.59s
# 108:	learn: 0.0950764	total: 1.27s	remaining: 4.57s
# 109:	learn: 0.0947427	total: 1.29s	remaining: 4.57s
# 110:	learn: 0.0942777	total: 1.3s	remaining: 4.55s
# 111:	learn: 0.0938502	total: 1.31s	remaining: 4.55s
# 112:	learn: 0.0933514	total: 1.33s	remaining: 4.57s
# 113:	learn: 0.0930062	total: 1.35s	remaining: 4.56s
# 114:	learn: 0.0925630	total: 1.36s	remaining: 4.55s
# 115:	learn: 0.0923425	total: 1.37s	remaining: 4.53s
# 116:	learn: 0.0920697	total: 1.38s	remaining: 4.51s
# 117:	learn: 0.0914202	total: 1.39s	remaining: 4.5s
# 118:	learn: 0.0912402	total: 1.4s	remaining: 4.49s
# 119:	learn: 0.0909189	total: 1.41s	remaining: 4.47s
# 120:	learn: 0.0895199	total: 1.42s	remaining: 4.46s
# 121:	learn: 0.0892674	total: 1.43s	remaining: 4.44s
# 122:	learn: 0.0889774	total: 1.44s	remaining: 4.42s
# 123:	learn: 0.0887979	total: 1.45s	remaining: 4.41s
# 124:	learn: 0.0882571	total: 1.46s	remaining: 4.39s
# 125:	learn: 0.0881448	total: 1.47s	remaining: 4.37s
# 126:	learn: 0.0880079	total: 1.5s	remaining: 4.39s
# 127:	learn: 0.0876812	total: 1.51s	remaining: 4.38s
# 128:	learn: 0.0874911	total: 1.52s	remaining: 4.36s
# 129:	learn: 0.0872633	total: 1.53s	remaining: 4.35s
# 130:	learn: 0.0870424	total: 1.54s	remaining: 4.33s
# 131:	learn: 0.0866679	total: 1.55s	remaining: 4.31s
# 132:	learn: 0.0863857	total: 1.56s	remaining: 4.3s
# 133:	learn: 0.0861088	total: 1.57s	remaining: 4.28s
# 134:	learn: 0.0858447	total: 1.58s	remaining: 4.27s
# 135:	learn: 0.0857046	total: 1.59s	remaining: 4.25s
# 136:	learn: 0.0854894	total: 1.6s	remaining: 4.24s
# 137:	learn: 0.0852780	total: 1.62s	remaining: 4.24s
# 138:	learn: 0.0845776	total: 1.63s	remaining: 4.25s
# 139:	learn: 0.0843026	total: 1.65s	remaining: 4.25s
# 140:	learn: 0.0842010	total: 1.67s	remaining: 4.24s
# 141:	learn: 0.0841152	total: 1.68s	remaining: 4.22s
# 142:	learn: 0.0840655	total: 1.69s	remaining: 4.21s
# 143:	learn: 0.0838712	total: 1.7s	remaining: 4.2s
# 144:	learn: 0.0836557	total: 1.71s	remaining: 4.19s
# 145:	learn: 0.0833326	total: 1.72s	remaining: 4.17s
# 146:	learn: 0.0827344	total: 1.73s	remaining: 4.16s
# 147:	learn: 0.0825409	total: 1.74s	remaining: 4.14s
# 148:	learn: 0.0823454	total: 1.75s	remaining: 4.13s
# 149:	learn: 0.0822136	total: 1.76s	remaining: 4.11s
# 150:	learn: 0.0819589	total: 1.77s	remaining: 4.09s
# 151:	learn: 0.0818572	total: 1.78s	remaining: 4.08s
# 152:	learn: 0.0816518	total: 1.79s	remaining: 4.06s
# 153:	learn: 0.0810389	total: 1.8s	remaining: 4.05s
# 154:	learn: 0.0807465	total: 1.81s	remaining: 4.04s
# 155:	learn: 0.0805487	total: 1.82s	remaining: 4.02s
# 156:	learn: 0.0803141	total: 1.83s	remaining: 4s
# 157:	learn: 0.0797845	total: 1.84s	remaining: 3.99s
# 158:	learn: 0.0795694	total: 1.85s	remaining: 3.98s
# 159:	learn: 0.0795049	total: 1.86s	remaining: 3.96s
# 160:	learn: 0.0792826	total: 1.88s	remaining: 3.96s
# 161:	learn: 0.0790830	total: 1.89s	remaining: 3.94s
# 162:	learn: 0.0787989	total: 1.91s	remaining: 3.94s
# 163:	learn: 0.0785466	total: 1.92s	remaining: 3.92s
# 164:	learn: 0.0783421	total: 1.93s	remaining: 3.91s
# 165:	learn: 0.0780977	total: 1.94s	remaining: 3.89s
# 166:	learn: 0.0779492	total: 1.95s	remaining: 3.88s
# 167:	learn: 0.0778871	total: 1.96s	remaining: 3.86s
# 168:	learn: 0.0776966	total: 1.97s	remaining: 3.85s
# 169:	learn: 0.0775191	total: 1.98s	remaining: 3.84s
# 170:	learn: 0.0774408	total: 1.99s	remaining: 3.82s
# 171:	learn: 0.0770197	total: 2s	remaining: 3.81s
# 172:	learn: 0.0768563	total: 2.01s	remaining: 3.79s
# 173:	learn: 0.0767199	total: 2.02s	remaining: 3.78s
# 174:	learn: 0.0766166	total: 2.03s	remaining: 3.77s
# 175:	learn: 0.0764072	total: 2.04s	remaining: 3.76s
# 176:	learn: 0.0761155	total: 2.05s	remaining: 3.75s
# 177:	learn: 0.0759631	total: 2.06s	remaining: 3.73s
# 178:	learn: 0.0756756	total: 2.07s	remaining: 3.72s
# 179:	learn: 0.0755023	total: 2.08s	remaining: 3.7s
# 180:	learn: 0.0752113	total: 2.09s	remaining: 3.69s
# 181:	learn: 0.0750901	total: 2.11s	remaining: 3.68s
# 182:	learn: 0.0748974	total: 2.12s	remaining: 3.67s
# 183:	learn: 0.0748576	total: 2.13s	remaining: 3.65s
# 184:	learn: 0.0745850	total: 2.14s	remaining: 3.64s
# 185:	learn: 0.0742678	total: 2.15s	remaining: 3.63s
# 186:	learn: 0.0740327	total: 2.16s	remaining: 3.61s
# 187:	learn: 0.0737358	total: 2.17s	remaining: 3.6s
# 188:	learn: 0.0736341	total: 2.18s	remaining: 3.59s
# 189:	learn: 0.0734562	total: 2.19s	remaining: 3.57s
# 190:	learn: 0.0731880	total: 2.2s	remaining: 3.56s
# 191:	learn: 0.0730041	total: 2.21s	remaining: 3.55s
# 192:	learn: 0.0729051	total: 2.22s	remaining: 3.54s
# 193:	learn: 0.0726747	total: 2.23s	remaining: 3.52s
# 194:	learn: 0.0725163	total: 2.24s	remaining: 3.51s
# 195:	learn: 0.0724564	total: 2.25s	remaining: 3.49s
# 196:	learn: 0.0723586	total: 2.26s	remaining: 3.48s
# 197:	learn: 0.0722348	total: 2.27s	remaining: 3.47s
# 198:	learn: 0.0720726	total: 2.28s	remaining: 3.45s
# 199:	learn: 0.0719155	total: 2.29s	remaining: 3.44s
# 200:	learn: 0.0716987	total: 2.3s	remaining: 3.43s
# 201:	learn: 0.0714971	total: 2.33s	remaining: 3.44s
# 202:	learn: 0.0712814	total: 2.35s	remaining: 3.44s
# 203:	learn: 0.0711356	total: 2.36s	remaining: 3.43s
# 204:	learn: 0.0709354	total: 2.38s	remaining: 3.42s
# 205:	learn: 0.0708068	total: 2.38s	remaining: 3.4s
# 206:	learn: 0.0705932	total: 2.4s	remaining: 3.39s
# 207:	learn: 0.0705278	total: 2.41s	remaining: 3.38s
# 208:	learn: 0.0703661	total: 2.42s	remaining: 3.36s
# 209:	learn: 0.0701972	total: 2.43s	remaining: 3.35s
# 210:	learn: 0.0701169	total: 2.44s	remaining: 3.34s
# 211:	learn: 0.0699346	total: 2.45s	remaining: 3.33s
# 212:	learn: 0.0697298	total: 2.46s	remaining: 3.31s
# 213:	learn: 0.0695891	total: 2.47s	remaining: 3.3s
# 214:	learn: 0.0692878	total: 2.48s	remaining: 3.29s
# 215:	learn: 0.0691231	total: 2.49s	remaining: 3.27s
# 216:	learn: 0.0689177	total: 2.5s	remaining: 3.26s
# 217:	learn: 0.0687228	total: 2.51s	remaining: 3.25s
# 218:	learn: 0.0685761	total: 2.52s	remaining: 3.23s
# 219:	learn: 0.0683468	total: 2.54s	remaining: 3.23s
# 220:	learn: 0.0682590	total: 2.55s	remaining: 3.21s
# 221:	learn: 0.0680564	total: 2.56s	remaining: 3.2s
# 222:	learn: 0.0679509	total: 2.57s	remaining: 3.19s
# 223:	learn: 0.0679148	total: 2.58s	remaining: 3.18s
# 224:	learn: 0.0676859	total: 2.6s	remaining: 3.17s
# 225:	learn: 0.0675644	total: 2.62s	remaining: 3.18s
# 226:	learn: 0.0674532	total: 2.63s	remaining: 3.17s
# 227:	learn: 0.0673260	total: 2.65s	remaining: 3.16s
# 228:	learn: 0.0672119	total: 2.65s	remaining: 3.14s
# 229:	learn: 0.0669947	total: 2.67s	remaining: 3.13s
# 230:	learn: 0.0668907	total: 2.68s	remaining: 3.12s
# 231:	learn: 0.0668601	total: 2.69s	remaining: 3.1s
# 232:	learn: 0.0668212	total: 2.7s	remaining: 3.09s
# 233:	learn: 0.0667308	total: 2.71s	remaining: 3.08s
# 234:	learn: 0.0665594	total: 2.72s	remaining: 3.07s
# 235:	learn: 0.0662427	total: 2.73s	remaining: 3.05s
# 236:	learn: 0.0662286	total: 2.74s	remaining: 3.04s
# 237:	learn: 0.0659962	total: 2.75s	remaining: 3.03s
# 238:	learn: 0.0657329	total: 2.76s	remaining: 3.02s
# 239:	learn: 0.0656371	total: 2.77s	remaining: 3.01s
# 240:	learn: 0.0655541	total: 2.78s	remaining: 2.99s
# 241:	learn: 0.0653530	total: 2.79s	remaining: 2.98s
# 242:	learn: 0.0650930	total: 2.81s	remaining: 2.97s
# 243:	learn: 0.0647226	total: 2.82s	remaining: 2.96s
# 244:	learn: 0.0645947	total: 2.83s	remaining: 2.94s
# 245:	learn: 0.0644474	total: 2.84s	remaining: 2.93s
# 246:	learn: 0.0642415	total: 2.85s	remaining: 2.92s
# 247:	learn: 0.0640642	total: 2.86s	remaining: 2.9s
# 248:	learn: 0.0638817	total: 2.87s	remaining: 2.89s
# 249:	learn: 0.0637678	total: 2.88s	remaining: 2.88s
# 250:	learn: 0.0636951	total: 2.89s	remaining: 2.87s
# 251:	learn: 0.0635456	total: 2.9s	remaining: 2.85s
# 252:	learn: 0.0634462	total: 2.91s	remaining: 2.84s
# 253:	learn: 0.0633622	total: 2.92s	remaining: 2.83s
# 254:	learn: 0.0633179	total: 2.93s	remaining: 2.81s
# 255:	learn: 0.0630523	total: 2.94s	remaining: 2.8s
# 256:	learn: 0.0629572	total: 2.95s	remaining: 2.79s
# 257:	learn: 0.0628411	total: 2.96s	remaining: 2.78s
# 258:	learn: 0.0628003	total: 2.97s	remaining: 2.77s
# 259:	learn: 0.0626482	total: 2.98s	remaining: 2.75s
# 260:	learn: 0.0626135	total: 2.99s	remaining: 2.74s
# 261:	learn: 0.0624256	total: 3s	remaining: 2.73s
# 262:	learn: 0.0622357	total: 3.02s	remaining: 2.72s
# 263:	learn: 0.0621241	total: 3.02s	remaining: 2.7s
# 264:	learn: 0.0619725	total: 3.04s	remaining: 2.69s
# 265:	learn: 0.0618615	total: 3.05s	remaining: 2.68s
# 266:	learn: 0.0616451	total: 3.06s	remaining: 2.67s
# 267:	learn: 0.0613573	total: 3.07s	remaining: 2.66s
# 268:	learn: 0.0612731	total: 3.08s	remaining: 2.65s
# 269:	learn: 0.0611359	total: 3.09s	remaining: 2.63s
# 270:	learn: 0.0610440	total: 3.1s	remaining: 2.62s
# 271:	learn: 0.0609312	total: 3.11s	remaining: 2.61s
# 272:	learn: 0.0608245	total: 3.12s	remaining: 2.6s
# 273:	learn: 0.0606033	total: 3.13s	remaining: 2.58s
# 274:	learn: 0.0605269	total: 3.14s	remaining: 2.57s
# 275:	learn: 0.0603849	total: 3.16s	remaining: 2.56s
# 276:	learn: 0.0602840	total: 3.17s	remaining: 2.55s
# 277:	learn: 0.0600795	total: 3.18s	remaining: 2.54s
# 278:	learn: 0.0599578	total: 3.19s	remaining: 2.53s
# 279:	learn: 0.0597630	total: 3.2s	remaining: 2.52s
# 280:	learn: 0.0596787	total: 3.21s	remaining: 2.5s
# 281:	learn: 0.0595463	total: 3.22s	remaining: 2.49s
# 282:	learn: 0.0595022	total: 3.23s	remaining: 2.48s
# 283:	learn: 0.0593485	total: 3.24s	remaining: 2.47s
# 284:	learn: 0.0592988	total: 3.25s	remaining: 2.46s
# 285:	learn: 0.0591622	total: 3.26s	remaining: 2.44s
# 286:	learn: 0.0590660	total: 3.27s	remaining: 2.43s
# 287:	learn: 0.0588478	total: 3.29s	remaining: 2.42s
# 288:	learn: 0.0588103	total: 3.29s	remaining: 2.4s
# 289:	learn: 0.0587375	total: 3.31s	remaining: 2.39s
# 290:	learn: 0.0586528	total: 3.32s	remaining: 2.38s
# 291:	learn: 0.0584886	total: 3.33s	remaining: 2.37s
# 292:	learn: 0.0583311	total: 3.36s	remaining: 2.37s
# 293:	learn: 0.0583064	total: 3.37s	remaining: 2.36s
# 294:	learn: 0.0582819	total: 3.38s	remaining: 2.35s
# 295:	learn: 0.0581900	total: 3.4s	remaining: 2.34s
# 296:	learn: 0.0581300	total: 3.4s	remaining: 2.33s
# 297:	learn: 0.0579867	total: 3.42s	remaining: 2.31s
# 298:	learn: 0.0577821	total: 3.43s	remaining: 2.3s
# 299:	learn: 0.0577372	total: 3.44s	remaining: 2.29s
# 300:	learn: 0.0575936	total: 3.45s	remaining: 2.28s
# 301:	learn: 0.0575185	total: 3.46s	remaining: 2.27s
# 302:	learn: 0.0574021	total: 3.47s	remaining: 2.25s
# 303:	learn: 0.0573369	total: 3.48s	remaining: 2.24s
# 304:	learn: 0.0571221	total: 3.49s	remaining: 2.23s
# 305:	learn: 0.0570206	total: 3.5s	remaining: 2.22s
# 306:	learn: 0.0569283	total: 3.51s	remaining: 2.21s
# 307:	learn: 0.0566945	total: 3.52s	remaining: 2.19s
# 308:	learn: 0.0565253	total: 3.53s	remaining: 2.18s
# 309:	learn: 0.0564085	total: 3.54s	remaining: 2.17s
# 310:	learn: 0.0563524	total: 3.55s	remaining: 2.16s
# 311:	learn: 0.0562581	total: 3.57s	remaining: 2.15s
# 312:	learn: 0.0562056	total: 3.59s	remaining: 2.14s
# 313:	learn: 0.0560723	total: 3.6s	remaining: 2.13s
# 314:	learn: 0.0559509	total: 3.61s	remaining: 2.12s
# 315:	learn: 0.0558065	total: 3.62s	remaining: 2.11s
# 316:	learn: 0.0557230	total: 3.63s	remaining: 2.1s
# 317:	learn: 0.0555996	total: 3.64s	remaining: 2.08s
# 318:	learn: 0.0554662	total: 3.65s	remaining: 2.07s
# 319:	learn: 0.0553521	total: 3.66s	remaining: 2.06s
# 320:	learn: 0.0552277	total: 3.67s	remaining: 2.05s
# 321:	learn: 0.0551182	total: 3.68s	remaining: 2.04s
# 322:	learn: 0.0550585	total: 3.69s	remaining: 2.02s
# 323:	learn: 0.0549306	total: 3.71s	remaining: 2.02s
# 324:	learn: 0.0548839	total: 3.72s	remaining: 2s
# 325:	learn: 0.0548117	total: 3.73s	remaining: 1.99s
# 326:	learn: 0.0547254	total: 3.74s	remaining: 1.98s
# 327:	learn: 0.0545388	total: 3.75s	remaining: 1.97s
# 328:	learn: 0.0544384	total: 3.76s	remaining: 1.95s
# 329:	learn: 0.0544150	total: 3.77s	remaining: 1.94s
# 330:	learn: 0.0543145	total: 3.78s	remaining: 1.93s
# 331:	learn: 0.0541775	total: 3.79s	remaining: 1.92s
# 332:	learn: 0.0540980	total: 3.8s	remaining: 1.91s
# 333:	learn: 0.0539981	total: 3.81s	remaining: 1.9s
# 334:	learn: 0.0538789	total: 3.82s	remaining: 1.88s
# 335:	learn: 0.0537939	total: 3.83s	remaining: 1.87s
# 336:	learn: 0.0536779	total: 3.85s	remaining: 1.86s
# 337:	learn: 0.0535613	total: 3.86s	remaining: 1.85s
# 338:	learn: 0.0535049	total: 3.87s	remaining: 1.84s
# 339:	learn: 0.0534374	total: 3.88s	remaining: 1.82s
# 340:	learn: 0.0533278	total: 3.88s	remaining: 1.81s
# 341:	learn: 0.0532602	total: 3.9s	remaining: 1.8s
# 342:	learn: 0.0531621	total: 3.91s	remaining: 1.79s
# 343:	learn: 0.0529973	total: 3.92s	remaining: 1.78s
# 344:	learn: 0.0528385	total: 3.93s	remaining: 1.76s
# 345:	learn: 0.0527740	total: 3.94s	remaining: 1.75s
# 346:	learn: 0.0527083	total: 3.95s	remaining: 1.74s
# 347:	learn: 0.0525404	total: 3.96s	remaining: 1.73s
# 348:	learn: 0.0524662	total: 3.97s	remaining: 1.72s
# 349:	learn: 0.0523492	total: 3.98s	remaining: 1.71s
# 350:	learn: 0.0522975	total: 3.99s	remaining: 1.69s
# 351:	learn: 0.0521522	total: 4s	remaining: 1.68s
# 352:	learn: 0.0521252	total: 4.01s	remaining: 1.67s
# 353:	learn: 0.0520199	total: 4.02s	remaining: 1.66s
# 354:	learn: 0.0519987	total: 4.03s	remaining: 1.65s
# 355:	learn: 0.0519381	total: 4.04s	remaining: 1.64s
# 356:	learn: 0.0519102	total: 4.05s	remaining: 1.62s
# 357:	learn: 0.0518462	total: 4.06s	remaining: 1.61s
# 358:	learn: 0.0516547	total: 4.09s	remaining: 1.6s
# 359:	learn: 0.0515185	total: 4.11s	remaining: 1.6s
# 360:	learn: 0.0514165	total: 4.13s	remaining: 1.59s
# 361:	learn: 0.0513287	total: 4.15s	remaining: 1.58s
# 362:	learn: 0.0512396	total: 4.16s	remaining: 1.57s
# 363:	learn: 0.0511338	total: 4.17s	remaining: 1.56s
# 364:	learn: 0.0510450	total: 4.19s	remaining: 1.55s
# 365:	learn: 0.0509540	total: 4.2s	remaining: 1.54s
# 366:	learn: 0.0508394	total: 4.21s	remaining: 1.52s
# 367:	learn: 0.0507266	total: 4.22s	remaining: 1.51s
# 368:	learn: 0.0506090	total: 4.23s	remaining: 1.5s
# 369:	learn: 0.0505116	total: 4.24s	remaining: 1.49s
# 370:	learn: 0.0503841	total: 4.25s	remaining: 1.48s
# 371:	learn: 0.0501911	total: 4.26s	remaining: 1.47s
# 372:	learn: 0.0500702	total: 4.27s	remaining: 1.45s
# 373:	learn: 0.0500164	total: 4.29s	remaining: 1.44s
# 374:	learn: 0.0498250	total: 4.3s	remaining: 1.43s
# 375:	learn: 0.0497157	total: 4.31s	remaining: 1.42s
# 376:	learn: 0.0496772	total: 4.32s	remaining: 1.41s
# 377:	learn: 0.0495755	total: 4.33s	remaining: 1.4s
# 378:	learn: 0.0495174	total: 4.35s	remaining: 1.39s
# 379:	learn: 0.0494352	total: 4.37s	remaining: 1.38s
# 380:	learn: 0.0493681	total: 4.38s	remaining: 1.37s
# 381:	learn: 0.0492752	total: 4.39s	remaining: 1.36s
# 382:	learn: 0.0491509	total: 4.4s	remaining: 1.34s
# 383:	learn: 0.0489584	total: 4.41s	remaining: 1.33s
# 384:	learn: 0.0489337	total: 4.42s	remaining: 1.32s
# 385:	learn: 0.0488334	total: 4.43s	remaining: 1.31s
# 386:	learn: 0.0487605	total: 4.45s	remaining: 1.3s
# 387:	learn: 0.0487497	total: 4.46s	remaining: 1.29s
# 388:	learn: 0.0486639	total: 4.47s	remaining: 1.27s
# 389:	learn: 0.0486569	total: 4.48s	remaining: 1.26s
# 390:	learn: 0.0485958	total: 4.49s	remaining: 1.25s
# 391:	learn: 0.0485164	total: 4.5s	remaining: 1.24s
# 392:	learn: 0.0484648	total: 4.51s	remaining: 1.23s
# 393:	learn: 0.0484039	total: 4.52s	remaining: 1.22s
# 394:	learn: 0.0483566	total: 4.53s	remaining: 1.2s
# 395:	learn: 0.0482864	total: 4.55s	remaining: 1.19s
# 396:	learn: 0.0480914	total: 4.56s	remaining: 1.18s
# 397:	learn: 0.0480631	total: 4.57s	remaining: 1.17s
# 398:	learn: 0.0479990	total: 4.58s	remaining: 1.16s
# 399:	learn: 0.0478523	total: 4.6s	remaining: 1.15s
# 400:	learn: 0.0477492	total: 4.61s	remaining: 1.14s
# 401:	learn: 0.0476585	total: 4.62s	remaining: 1.13s
# 402:	learn: 0.0476510	total: 4.63s	remaining: 1.11s
# 403:	learn: 0.0475419	total: 4.64s	remaining: 1.1s
# 404:	learn: 0.0474492	total: 4.65s	remaining: 1.09s
# 405:	learn: 0.0473819	total: 4.66s	remaining: 1.08s
# 406:	learn: 0.0472844	total: 4.67s	remaining: 1.07s
# 407:	learn: 0.0471582	total: 4.68s	remaining: 1.05s
# 408:	learn: 0.0471306	total: 4.69s	remaining: 1.04s
# 409:	learn: 0.0470975	total: 4.7s	remaining: 1.03s
# 410:	learn: 0.0469865	total: 4.71s	remaining: 1.02s
# 411:	learn: 0.0469394	total: 4.72s	remaining: 1.01s
# 412:	learn: 0.0468375	total: 4.73s	remaining: 997ms
# 413:	learn: 0.0467303	total: 4.74s	remaining: 985ms
# 414:	learn: 0.0466050	total: 4.75s	remaining: 973ms
# 415:	learn: 0.0465028	total: 4.76s	remaining: 961ms
# 416:	learn: 0.0464380	total: 4.77s	remaining: 950ms
# 417:	learn: 0.0463727	total: 4.78s	remaining: 938ms
# 418:	learn: 0.0462571	total: 4.8s	remaining: 928ms
# 419:	learn: 0.0461935	total: 4.81s	remaining: 917ms
# 420:	learn: 0.0461697	total: 4.82s	remaining: 905ms
# 421:	learn: 0.0460859	total: 4.83s	remaining: 893ms
# 422:	learn: 0.0460501	total: 4.84s	remaining: 882ms
# 423:	learn: 0.0459771	total: 4.85s	remaining: 870ms
# 424:	learn: 0.0459604	total: 4.86s	remaining: 858ms
# 425:	learn: 0.0459165	total: 4.87s	remaining: 846ms
# 426:	learn: 0.0458657	total: 4.88s	remaining: 835ms
# 427:	learn: 0.0457678	total: 4.89s	remaining: 823ms
# 428:	learn: 0.0456895	total: 4.9s	remaining: 812ms
# 429:	learn: 0.0456241	total: 4.92s	remaining: 800ms
# 430:	learn: 0.0455694	total: 4.92s	remaining: 789ms
# 431:	learn: 0.0455062	total: 4.93s	remaining: 777ms
# 432:	learn: 0.0454499	total: 4.95s	remaining: 765ms
# 433:	learn: 0.0453712	total: 4.96s	remaining: 754ms
# 434:	learn: 0.0453326	total: 4.97s	remaining: 742ms
# 435:	learn: 0.0451032	total: 4.98s	remaining: 731ms
# 436:	learn: 0.0450610	total: 4.99s	remaining: 719ms
# 437:	learn: 0.0449964	total: 5s	remaining: 707ms
# 438:	learn: 0.0449503	total: 5.01s	remaining: 696ms
# 439:	learn: 0.0449120	total: 5.02s	remaining: 685ms
# 440:	learn: 0.0448024	total: 5.03s	remaining: 673ms
# 441:	learn: 0.0447302	total: 5.04s	remaining: 662ms
# 442:	learn: 0.0446110	total: 5.05s	remaining: 650ms
# 443:	learn: 0.0445367	total: 5.06s	remaining: 638ms
# 444:	learn: 0.0444920	total: 5.07s	remaining: 627ms
# 445:	learn: 0.0444395	total: 5.08s	remaining: 615ms
# 446:	learn: 0.0444036	total: 5.09s	remaining: 604ms
# 447:	learn: 0.0443545	total: 5.1s	remaining: 592ms
# 448:	learn: 0.0443096	total: 5.11s	remaining: 581ms
# 449:	learn: 0.0442430	total: 5.12s	remaining: 569ms
# 450:	learn: 0.0442032	total: 5.13s	remaining: 558ms
# 451:	learn: 0.0441674	total: 5.14s	remaining: 546ms
# 452:	learn: 0.0441417	total: 5.15s	remaining: 535ms
# 453:	learn: 0.0440675	total: 5.16s	remaining: 523ms
# 454:	learn: 0.0439939	total: 5.18s	remaining: 513ms
# 455:	learn: 0.0438772	total: 5.19s	remaining: 501ms
# 456:	learn: 0.0438147	total: 5.2s	remaining: 490ms
# 457:	learn: 0.0437369	total: 5.22s	remaining: 478ms
# 458:	learn: 0.0436501	total: 5.23s	remaining: 467ms
# 459:	learn: 0.0435488	total: 5.24s	remaining: 456ms
# 460:	learn: 0.0434283	total: 5.25s	remaining: 444ms
# 461:	learn: 0.0433470	total: 5.26s	remaining: 433ms
# 462:	learn: 0.0432288	total: 5.27s	remaining: 421ms
# 463:	learn: 0.0431722	total: 5.28s	remaining: 410ms
# 464:	learn: 0.0431438	total: 5.29s	remaining: 398ms
# 465:	learn: 0.0430371	total: 5.3s	remaining: 387ms
# 466:	learn: 0.0429222	total: 5.32s	remaining: 376ms
# 467:	learn: 0.0429088	total: 5.33s	remaining: 364ms
# 468:	learn: 0.0428487	total: 5.33s	remaining: 353ms
# 469:	learn: 0.0427499	total: 5.36s	remaining: 342ms
# 470:	learn: 0.0426736	total: 5.37s	remaining: 331ms
# 471:	learn: 0.0425759	total: 5.38s	remaining: 319ms
# 472:	learn: 0.0424844	total: 5.39s	remaining: 308ms
# 473:	learn: 0.0424348	total: 5.41s	remaining: 296ms
# 474:	learn: 0.0424027	total: 5.42s	remaining: 285ms
# 475:	learn: 0.0422993	total: 5.43s	remaining: 274ms
# 476:	learn: 0.0422402	total: 5.44s	remaining: 262ms
# 477:	learn: 0.0421356	total: 5.45s	remaining: 251ms
# 478:	learn: 0.0420367	total: 5.46s	remaining: 239ms
# 479:	learn: 0.0419084	total: 5.47s	remaining: 228ms
# 480:	learn: 0.0418489	total: 5.48s	remaining: 217ms
# 481:	learn: 0.0418060	total: 5.49s	remaining: 205ms
# 482:	learn: 0.0416658	total: 5.5s	remaining: 194ms
# 483:	learn: 0.0416131	total: 5.52s	remaining: 182ms
# 484:	learn: 0.0414675	total: 5.53s	remaining: 171ms
# 485:	learn: 0.0413994	total: 5.54s	remaining: 160ms
# 486:	learn: 0.0412793	total: 5.55s	remaining: 148ms
# 487:	learn: 0.0411831	total: 5.57s	remaining: 137ms
# 488:	learn: 0.0411022	total: 5.58s	remaining: 126ms
# 489:	learn: 0.0409597	total: 5.59s	remaining: 114ms
# 490:	learn: 0.0409460	total: 5.6s	remaining: 103ms
# 491:	learn: 0.0409216	total: 5.61s	remaining: 91.2ms
# 492:	learn: 0.0408703	total: 5.62s	remaining: 79.9ms
# 493:	learn: 0.0408537	total: 5.63s	remaining: 68.4ms
# 494:	learn: 0.0407817	total: 5.64s	remaining: 57ms
# 495:	learn: 0.0407157	total: 5.67s	remaining: 45.7ms
# 496:	learn: 0.0406901	total: 5.69s	remaining: 34.3ms
# 497:	learn: 0.0405720	total: 5.7s	remaining: 22.9ms
# 498:	learn: 0.0405178	total: 5.73s	remaining: 11.5ms
# 499:	learn: 0.0404251	total: 5.74s	remaining: 0us

# %%
from sklearn.metrics import f1_score

f1_score(pred, val_y)
# Out:
# 0.68135593220339

# %%
pred_cb = model.predict_proba(X_train_over)

# %% [markdown]
# ##### 2) XGB Classifier

# %%
import xgboost as xgb

clf =xgb.XGBClassifier(max_depth =17, min_child_weight = 1, n_estimators = 120, random_state = 0)#,learning_rate = 0.1,  objective = 'binary:logistic' ,)
clf.fit(X_train_over, y_train_over)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=17, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=120, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...)

# %%
from sklearn.metrics import f1_score
pred = clf.predict(val_X)
f1_score(pred, val_y)
# Out:
# 0.6821192052980133

# %%
pred_xgb = clf.predict_proba(X_train_over)

# %% [markdown]
# ##### 3) Histrogram-based Gradient Bosting

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

hgb = HistGradientBoostingClassifier(random_state = 0, max_depth = 17, learning_rate = 0.2)
hgb.fit(X_train_over, y_train_over)
# Out:
# HistGradientBoostingClassifier(learning_rate=0.2, max_depth=17, random_state=0)

# %%
from sklearn.metrics import f1_score
pred = hgb.predict(val_X)
f1_score(pred, val_y)
# Out:
# 0.6789915966386555

# %%
# 32, 0.4 : 0.573099
# 20, 0.1 : 0.608163
# 15, 0.1 : 0.604
# 15, 0.01 : 0.504
# 15, 0.2 : 0.64055299 <- PICK
# 18, 0.2 :0.6241457
# 20, 0.2 : 0.62414578
# 13, 0.2 : 0.607888
# 16, 0.2 : 0.6178489
# 15, 0.3 :0.6124409
# 15, 0.4 : 0.625390

from sklearn.metrics import f1_score
pred = hgb.predict(val_X)
f1_score(pred, val_y)
# Out:
# 0.6730769230769232

# %%
pred_hgb = hgb.predict_proba(X_train_over)

# %% [markdown]
# ##### 3) LightGBM Classifier

# %%
import lightgbm as lgb

lgb = lgb.LGBMClassifier(boosting_type	= 'gbdt', max_depth = 12,
                         learning_rate = 0.2, n_estimators = 150,random_state = 0,force_col_wise=True,
                         feature_fraction = 0.4 )
# feature_fraction : 각각의 iteration 반복에서 변수(features)의 몇 %를 랜덤하게 쓸 것인가 결정.
lgb.fit(X_train_over, y_train_over)
pred = lgb.predict(val_X)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 9024, number of negative: 9024
# [LightGBM] [Info] Total Bins 7779
# [LightGBM] [Info] Number of data points in the train set: 18048, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
from sklearn.metrics import f1_score
f1_score(pred, val_y)
# Out:
# 0.6839378238341969

# %%
pred_lgbm = lgb.predict_proba(X_train_over)

# %% [markdown]
# ##### 4) RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=0, max_depth=18, min_samples_leaf=3, min_samples_split=2, n_estimators=90)
rf.fit(X_train_over, y_train_over)
pred = rf.predict(val_X)

# %%
from sklearn.metrics import f1_score
f1_score(pred, val_y)

# %%
pred_rf = rf.predict_proba(X_train_over)

# %% [markdown]
# ##### 5) Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(min_samples_leaf =3, random_state=0, max_depth = 12, learning_rate = 0.2) # 기본값: max_depth=3, learning_rate=0.1
gbc.fit(X_train_over, y_train_over)
# Out:
# GradientBoostingClassifier(learning_rate=0.2, max_depth=12, min_samples_leaf=3,
#                            random_state=0)

# %%
# 3, 12, 0.1 : 0.700507  <- PICK
# 2, 11, 0.2 : 0.68062
# 2, 11, 0.1 : 0.690355
# 2, 12, 0.1 :0.69565217
# 2, 13, 0.1 : 0.69387755

from sklearn.metrics import f1_score
pred = gbc.predict(val_X)
f1_score(pred, val_y)
# Out:
# 0.6723259762308998

# %%
pred_gbc = gbc.predict_proba(X_train_over)

# %% [markdown]
# ##### Stacking

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.4.2)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5

# %%
from catboost import CatBoostClassifier, Pool
import xgboost as xgb
from sklearn.ensemble import HistGradientBoostingClassifier
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings(action = 'ignore')

# 개별 모델
cat_clf = CatBoostClassifier(iterations=500, depth=7, learning_rate=0.4,loss_function='Logloss',verbose=True,random_state = 0)
xgb_clf = xgb.XGBClassifier(max_depth =12, min_child_weight = 1, n_estimators = 100, random_state = 0)#,learning_rate = 0.1,  objective = 'binary:logistic' ,)
# hgb_clf = HistGradientBoostingClassifier(random_state = 0, max_depth = 14, learning_rate = 0.2)
lgb_clf = lgb.LGBMClassifier(boosting_type	= 'gbdt', max_depth = 25, learning_rate = 0.1, n_estimators = 500,random_state = 0,force_col_wise=True, feature_fraction = 1 )
rf_clf = RandomForestClassifier(random_state=0, max_depth=18, min_samples_leaf=3, min_samples_split=3, n_estimators=90)

# 최종 메타 모델
gbc_final = GradientBoostingClassifier(min_samples_leaf =4,  max_depth = 15, learning_rate = 0.2) #

# %%
# 개별모델 내부에서 CV 적용 => Stacking
def get_stacking_datasets(model, x_train_n, y_train_n, x_test_n, n_folds) :
  # K-fold 설정
  kf = KFold(n_splits=n_folds, shuffle = False)#, random_state = 0)#, shuffle = False,

  # 최종 메타 모델이 사용할 학습데이터 반환을 위해 넘파이 배열을 0으로 만듦
  train_fold_pred = np.zeros((x_train_n.shape[0], 1))
  test_pred = np.zeros((x_test_n.shape[0], n_folds))
  # print(model.__class__.name__, '모델 시작')

  for folder_counter, (train_idx, valid_idx) in enumerate(kf.split(x_train_n)):
    # 개별 모델 학습하고 1개의 fold로 예측할 데이터 셋 추출
    print(f" Fold 횟수 : {folder_counter+1}")
    x_tr = x_train_n.iloc[train_idx,:]
    y_tr = y_train_n[train_idx]
    x_te = x_train_n.iloc[valid_idx,:]

    # 개별 모델 학습 후 1개의 fold 데이터셋으로 예측값 반환후 최종 메타모델이 학습할 데이터셋에 추가
    model.fit(x_tr, y_tr)
    train_fold_pred[valid_idx, :] = model.predict(x_te).reshape(-1,1)
    # 개별 모델이 검증 데이터셋을 기반으로 예측 결과값 반환 후 최종 메타모델이 검증할 데이터셋에 추가
    test_pred[:, folder_counter] = model.predict(x_test_n)

  # 개별 모델 안에서 테스트 데이터셋을 기반으로 예측한 결과값의 평균을 구하고 2차원으로 바꾸기
  test_pred_mean = np.mean(test_pred, axis = 1).reshape(-1,1)

  return train_fold_pred, test_pred_mean

# %%
# 모든 변수 사용
cat_train, cat_test = get_stacking_datasets(cat_clf, X_train_over, y_train_over, val_X, 5)
xgb_train, xgb_test = get_stacking_datasets(xgb_clf, X_train_over, y_train_over, val_X, 5)
# hgb_train, hgb_test = get_stacking_datasets(hgb_clf, X_train_over[['AL', 'CA', 'YEAR', 'ANONYMOUS_1', 'ANONYMOUS_2', 'FE', 'SI']], y_train_over, val_X[['AL', 'CA', 'YEAR', 'ANONYMOUS_1', 'ANONYMOUS_2', 'FE', 'SI']], 5)
lgb_train, lgb_test = get_stacking_datasets(lgb_clf, X_train_over, y_train_over, val_X, 5)
# rf_train, rf_test = get_stacking_datasets(rf_clf, X_train_over, y_train_over, val_X, 5)
# Out:
#  Fold 횟수 : 1
# 0:	learn: 0.3716646	total: 25.8ms	remaining: 12.9s
# 1:	learn: 0.2665095	total: 45.3ms	remaining: 11.3s
# 2:	learn: 0.2084828	total: 65.8ms	remaining: 10.9s
# 3:	learn: 0.1838455	total: 85.9ms	remaining: 10.7s
# 4:	learn: 0.1598075	total: 111ms	remaining: 11s
# 5:	learn: 0.1398903	total: 135ms	remaining: 11.2s
# 6:	learn: 0.1295247	total: 157ms	remaining: 11.1s
# 7:	learn: 0.1245917	total: 176ms	remaining: 10.9s
# 8:	learn: 0.1174635	total: 198ms	remaining: 10.8s
# 9:	learn: 0.1136381	total: 217ms	remaining: 10.6s
# 10:	learn: 0.1050656	total: 238ms	remaining: 10.6s
# 11:	learn: 0.1017472	total: 258ms	remaining: 10.5s
# 12:	learn: 0.0979490	total: 280ms	remaining: 10.5s
# 13:	learn: 0.0922919	total: 300ms	remaining: 10.4s
# 14:	learn: 0.0882738	total: 320ms	remaining: 10.4s
# 15:	learn: 0.0852553	total: 343ms	remaining: 10.4s
# 16:	learn: 0.0824790	total: 363ms	remaining: 10.3s
# 17:	learn: 0.0807548	total: 383ms	remaining: 10.3s
# 18:	learn: 0.0790253	total: 403ms	remaining: 10.2s
# 19:	learn: 0.0771456	total: 422ms	remaining: 10.1s
# 20:	learn: 0.0752650	total: 444ms	remaining: 10.1s
# 21:	learn: 0.0729641	total: 465ms	remaining: 10.1s
# 22:	learn: 0.0710788	total: 487ms	remaining: 10.1s
# 23:	learn: 0.0698880	total: 507ms	remaining: 10.1s
# 24:	learn: 0.0684878	total: 528ms	remaining: 10s
# 25:	learn: 0.0657693	total: 551ms	remaining: 10s
# 26:	learn: 0.0644660	total: 571ms	remaining: 10s
# 27:	learn: 0.0632960	total: 594ms	remaining: 10s
# 28:	learn: 0.0623289	total: 617ms	remaining: 10s
# 29:	learn: 0.0602473	total: 638ms	remaining: 9.99s
# 30:	learn: 0.0580347	total: 658ms	remaining: 9.95s
# 31:	learn: 0.0562717	total: 678ms	remaining: 9.91s
# 32:	learn: 0.0551240	total: 698ms	remaining: 9.87s
# 33:	learn: 0.0547441	total: 717ms	remaining: 9.82s
# 34:	learn: 0.0533510	total: 742ms	remaining: 9.86s
# 35:	learn: 0.0519305	total: 766ms	remaining: 9.87s
# 36:	learn: 0.0501567	total: 787ms	remaining: 9.85s
# 37:	learn: 0.0489431	total: 807ms	remaining: 9.81s
# 38:	learn: 0.0487457	total: 826ms	remaining: 9.76s
# 39:	learn: 0.0467217	total: 847ms	remaining: 9.74s
# 40:	learn: 0.0454525	total: 868ms	remaining: 9.71s
# 41:	learn: 0.0446679	total: 894ms	remaining: 9.74s
# 42:	learn: 0.0443303	total: 923ms	remaining: 9.81s
# 43:	learn: 0.0434298	total: 943ms	remaining: 9.77s
# 44:	learn: 0.0429043	total: 962ms	remaining: 9.73s
# 45:	learn: 0.0414377	total: 986ms	remaining: 9.73s
# 46:	learn: 0.0403166	total: 1s	remaining: 9.69s
# 47:	learn: 0.0393605	total: 1.02s	remaining: 9.66s
# 48:	learn: 0.0387668	total: 1.04s	remaining: 9.62s
# 49:	learn: 0.0384244	total: 1.07s	remaining: 9.65s
# 50:	learn: 0.0377771	total: 1.1s	remaining: 9.65s
# 51:	learn: 0.0374585	total: 1.12s	remaining: 9.63s
# 52:	learn: 0.0367011	total: 1.14s	remaining: 9.59s
# 53:	learn: 0.0361146	total: 1.16s	remaining: 9.57s
# 54:	learn: 0.0351400	total: 1.18s	remaining: 9.54s
# 55:	learn: 0.0343834	total: 1.2s	remaining: 9.54s
# 56:	learn: 0.0331732	total: 1.22s	remaining: 9.51s
# 57:	learn: 0.0328660	total: 1.24s	remaining: 9.48s
# 58:	learn: 0.0323759	total: 1.26s	remaining: 9.44s
# 59:	learn: 0.0321387	total: 1.28s	remaining: 9.4s
# 60:	learn: 0.0317781	total: 1.3s	remaining: 9.36s
# 61:	learn: 0.0316338	total: 1.32s	remaining: 9.33s
# 62:	learn: 0.0315634	total: 1.34s	remaining: 9.29s
# 63:	learn: 0.0305260	total: 1.36s	remaining: 9.27s
# 64:	learn: 0.0295621	total: 1.38s	remaining: 9.24s
# 65:	learn: 0.0292665	total: 1.4s	remaining: 9.21s
# 66:	learn: 0.0287759	total: 1.42s	remaining: 9.2s
# 67:	learn: 0.0276392	total: 1.44s	remaining: 9.18s
# 68:	learn: 0.0274820	total: 1.46s	remaining: 9.15s
# 69:	learn: 0.0271569	total: 1.48s	remaining: 9.11s
# 70:	learn: 0.0264415	total: 1.51s	remaining: 9.12s
# 71:	learn: 0.0262994	total: 1.53s	remaining: 9.09s
# 72:	learn: 0.0262044	total: 1.55s	remaining: 9.05s
# 73:	learn: 0.0258915	total: 1.57s	remaining: 9.02s
# 74:	learn: 0.0253859	total: 1.59s	remaining: 9s
# 75:	learn: 0.0248748	total: 1.61s	remaining: 8.97s
# 76:	learn: 0.0245168	total: 1.63s	remaining: 8.97s
# 77:	learn: 0.0243112	total: 1.65s	remaining: 8.94s
# 78:	learn: 0.0237037	total: 1.67s	remaining: 8.92s
# 79:	learn: 0.0234944	total: 1.69s	remaining: 8.89s
# 80:	learn: 0.0230423	total: 1.72s	remaining: 8.88s
# 81:	learn: 0.0227481	total: 1.74s	remaining: 8.85s
# 82:	learn: 0.0226708	total: 1.75s	remaining: 8.82s
# 83:	learn: 0.0221811	total: 1.77s	remaining: 8.79s
# 84:	learn: 0.0217890	total: 1.79s	remaining: 8.77s
# 85:	learn: 0.0213677	total: 1.82s	remaining: 8.75s
# 86:	learn: 0.0210958	total: 1.84s	remaining: 8.74s
# 87:	learn: 0.0210052	total: 1.86s	remaining: 8.71s
# 88:	learn: 0.0207069	total: 1.89s	remaining: 8.71s
# 89:	learn: 0.0202680	total: 1.92s	remaining: 8.76s
# 90:	learn: 0.0200135	total: 1.94s	remaining: 8.74s
# 91:	learn: 0.0197911	total: 1.96s	remaining: 8.71s
# 92:	learn: 0.0197156	total: 1.98s	remaining: 8.68s
# 93:	learn: 0.0192178	total: 2s	remaining: 8.65s
# 94:	learn: 0.0189559	total: 2.02s	remaining: 8.62s
# 95:	learn: 0.0184267	total: 2.04s	remaining: 8.61s
# 96:	learn: 0.0181488	total: 2.06s	remaining: 8.58s
# 97:	learn: 0.0178019	total: 2.09s	remaining: 8.57s
# 98:	learn: 0.0176773	total: 2.11s	remaining: 8.54s
# 99:	learn: 0.0175916	total: 2.13s	remaining: 8.52s
# 100:	learn: 0.0174294	total: 2.15s	remaining: 8.5s
# 101:	learn: 0.0173581	total: 2.17s	remaining: 8.47s
# 102:	learn: 0.0173024	total: 2.19s	remaining: 8.44s
# 103:	learn: 0.0168956	total: 2.21s	remaining: 8.41s
# 104:	learn: 0.0163704	total: 2.23s	remaining: 8.4s
# 105:	learn: 0.0159714	total: 2.26s	remaining: 8.39s
# 106:	learn: 0.0157100	total: 2.28s	remaining: 8.37s
# 107:	learn: 0.0155689	total: 2.3s	remaining: 8.34s
# 108:	learn: 0.0153063	total: 2.32s	remaining: 8.31s
# 109:	learn: 0.0151290	total: 2.34s	remaining: 8.29s
# 110:	learn: 0.0150140	total: 2.36s	remaining: 8.26s
# 111:	learn: 0.0147367	total: 2.38s	remaining: 8.24s
# 112:	learn: 0.0144722	total: 2.4s	remaining: 8.22s
# 113:	learn: 0.0142784	total: 2.42s	remaining: 8.2s
# 114:	learn: 0.0141084	total: 2.44s	remaining: 8.17s
# 115:	learn: 0.0137870	total: 2.46s	remaining: 8.16s
# 116:	learn: 0.0136551	total: 2.48s	remaining: 8.13s
# 117:	learn: 0.0133489	total: 2.5s	remaining: 8.11s
# 118:	learn: 0.0133486	total: 2.52s	remaining: 8.08s
# 119:	learn: 0.0133484	total: 2.54s	remaining: 8.05s
# 120:	learn: 0.0132293	total: 2.56s	remaining: 8.03s
# 121:	learn: 0.0130810	total: 2.59s	remaining: 8.03s
# 122:	learn: 0.0130257	total: 2.61s	remaining: 8s
# 123:	learn: 0.0128375	total: 2.63s	remaining: 7.98s
# 124:	learn: 0.0126908	total: 2.65s	remaining: 7.96s
# 125:	learn: 0.0124514	total: 2.67s	remaining: 7.94s
# 126:	learn: 0.0122527	total: 2.7s	remaining: 7.92s
# 127:	learn: 0.0120532	total: 2.72s	remaining: 7.9s
# 128:	learn: 0.0118891	total: 2.74s	remaining: 7.88s
# 129:	learn: 0.0118891	total: 2.76s	remaining: 7.85s
# 130:	learn: 0.0116811	total: 2.78s	remaining: 7.83s
# 131:	learn: 0.0116010	total: 2.8s	remaining: 7.8s
# 132:	learn: 0.0116009	total: 2.82s	remaining: 7.78s
# 133:	learn: 0.0114489	total: 2.84s	remaining: 7.75s
# 134:	learn: 0.0113703	total: 2.86s	remaining: 7.73s
# 135:	learn: 0.0112050	total: 2.88s	remaining: 7.71s
# 136:	learn: 0.0111556	total: 2.9s	remaining: 7.69s
# 137:	learn: 0.0109741	total: 2.94s	remaining: 7.71s
# 138:	learn: 0.0107118	total: 2.96s	remaining: 7.68s
# 139:	learn: 0.0105378	total: 2.98s	remaining: 7.66s
# 140:	learn: 0.0104250	total: 3s	remaining: 7.64s
# 141:	learn: 0.0104249	total: 3.02s	remaining: 7.61s
# 142:	learn: 0.0104248	total: 3.03s	remaining: 7.58s
# 143:	learn: 0.0104248	total: 3.05s	remaining: 7.55s
# 144:	learn: 0.0104246	total: 3.08s	remaining: 7.53s
# 145:	learn: 0.0104243	total: 3.1s	remaining: 7.51s
# 146:	learn: 0.0104243	total: 3.12s	remaining: 7.49s
# 147:	learn: 0.0104241	total: 3.14s	remaining: 7.47s
# 148:	learn: 0.0104225	total: 3.16s	remaining: 7.45s
# 149:	learn: 0.0103967	total: 3.18s	remaining: 7.42s
# 150:	learn: 0.0102557	total: 3.2s	remaining: 7.4s
# 151:	learn: 0.0100524	total: 3.22s	remaining: 7.38s
# 152:	learn: 0.0099074	total: 3.24s	remaining: 7.35s
# 153:	learn: 0.0099074	total: 3.26s	remaining: 7.32s
# 154:	learn: 0.0097778	total: 3.28s	remaining: 7.3s
# 155:	learn: 0.0095206	total: 3.31s	remaining: 7.29s
# 156:	learn: 0.0095203	total: 3.32s	remaining: 7.26s
# 157:	learn: 0.0094047	total: 3.34s	remaining: 7.24s
# 158:	learn: 0.0093195	total: 3.36s	remaining: 7.21s
# 159:	learn: 0.0092511	total: 3.38s	remaining: 7.19s
# 160:	learn: 0.0091484	total: 3.4s	remaining: 7.17s
# 161:	learn: 0.0091337	total: 3.42s	remaining: 7.14s
# 162:	learn: 0.0090579	total: 3.44s	remaining: 7.12s
# 163:	learn: 0.0089824	total: 3.46s	remaining: 7.09s
# 164:	learn: 0.0088471	total: 3.48s	remaining: 7.07s
# 165:	learn: 0.0087177	total: 3.5s	remaining: 7.05s
# 166:	learn: 0.0087177	total: 3.53s	remaining: 7.04s
# 167:	learn: 0.0087171	total: 3.55s	remaining: 7.01s
# 168:	learn: 0.0087171	total: 3.57s	remaining: 6.99s
# 169:	learn: 0.0087095	total: 3.59s	remaining: 6.96s
# 170:	learn: 0.0087094	total: 3.61s	remaining: 6.94s
# 171:	learn: 0.0087093	total: 3.62s	remaining: 6.91s
# 172:	learn: 0.0087093	total: 3.64s	remaining: 6.88s
# 173:	learn: 0.0085870	total: 3.66s	remaining: 6.86s
# 174:	learn: 0.0084657	total: 3.68s	remaining: 6.84s
# 175:	learn: 0.0084652	total: 3.7s	remaining: 6.82s
# 176:	learn: 0.0084319	total: 3.72s	remaining: 6.8s
# 177:	learn: 0.0084317	total: 3.74s	remaining: 6.77s
# 178:	learn: 0.0082117	total: 3.77s	remaining: 6.75s
# 179:	learn: 0.0082116	total: 3.78s	remaining: 6.73s
# 180:	learn: 0.0081588	total: 3.81s	remaining: 6.71s
# 181:	learn: 0.0080057	total: 3.83s	remaining: 6.68s
# 182:	learn: 0.0079455	total: 3.85s	remaining: 6.66s
# 183:	learn: 0.0079454	total: 3.86s	remaining: 6.63s
# 184:	learn: 0.0078884	total: 3.88s	remaining: 6.61s
# 185:	learn: 0.0078042	total: 3.9s	remaining: 6.59s
# 186:	learn: 0.0078040	total: 3.92s	remaining: 6.56s
# 187:	learn: 0.0077281	total: 3.96s	remaining: 6.58s
# 188:	learn: 0.0077281	total: 3.98s	remaining: 6.55s
# 189:	learn: 0.0077280	total: 4s	remaining: 6.53s
# 190:	learn: 0.0076798	total: 4.02s	remaining: 6.51s
# 191:	learn: 0.0076281	total: 4.04s	remaining: 6.49s
# 192:	learn: 0.0075100	total: 4.07s	remaining: 6.47s
# 193:	learn: 0.0075094	total: 4.09s	remaining: 6.45s
# 194:	learn: 0.0075093	total: 4.11s	remaining: 6.42s
# 195:	learn: 0.0075090	total: 4.13s	remaining: 6.4s
# 196:	learn: 0.0075090	total: 4.14s	remaining: 6.37s
# 197:	learn: 0.0074571	total: 4.16s	remaining: 6.35s
# 198:	learn: 0.0074561	total: 4.19s	remaining: 6.33s
# 199:	learn: 0.0073219	total: 4.21s	remaining: 6.31s
# 200:	learn: 0.0072574	total: 4.23s	remaining: 6.29s
# 201:	learn: 0.0070961	total: 4.25s	remaining: 6.26s
# 202:	learn: 0.0070960	total: 4.26s	remaining: 6.24s
# 203:	learn: 0.0070154	total: 4.29s	remaining: 6.22s
# 204:	learn: 0.0069406	total: 4.31s	remaining: 6.2s
# 205:	learn: 0.0069406	total: 4.33s	remaining: 6.17s
# 206:	learn: 0.0068926	total: 4.35s	remaining: 6.15s
# 207:	learn: 0.0068369	total: 4.37s	remaining: 6.13s
# 208:	learn: 0.0068368	total: 4.38s	remaining: 6.1s
# 209:	learn: 0.0068367	total: 4.41s	remaining: 6.08s
# 210:	learn: 0.0068366	total: 4.42s	remaining: 6.06s
# 211:	learn: 0.0067699	total: 4.44s	remaining: 6.03s
# 212:	learn: 0.0067698	total: 4.46s	remaining: 6.01s
# 213:	learn: 0.0067697	total: 4.48s	remaining: 5.98s
# 214:	learn: 0.0067667	total: 4.5s	remaining: 5.97s
# 215:	learn: 0.0067583	total: 4.52s	remaining: 5.95s
# 216:	learn: 0.0067384	total: 4.54s	remaining: 5.92s
# 217:	learn: 0.0066611	total: 4.56s	remaining: 5.9s
# 218:	learn: 0.0066611	total: 4.58s	remaining: 5.88s
# 219:	learn: 0.0066594	total: 4.6s	remaining: 5.85s
# 220:	learn: 0.0065604	total: 4.62s	remaining: 5.83s
# 221:	learn: 0.0064917	total: 4.64s	remaining: 5.81s
# 222:	learn: 0.0063593	total: 4.66s	remaining: 5.79s
# 223:	learn: 0.0063070	total: 4.68s	remaining: 5.77s
# 224:	learn: 0.0063070	total: 4.7s	remaining: 5.75s
# 225:	learn: 0.0062317	total: 4.72s	remaining: 5.72s
# 226:	learn: 0.0062317	total: 4.74s	remaining: 5.7s
# 227:	learn: 0.0062317	total: 4.76s	remaining: 5.68s
# 228:	learn: 0.0062317	total: 4.8s	remaining: 5.68s
# 229:	learn: 0.0062316	total: 4.85s	remaining: 5.7s
# 230:	learn: 0.0062316	total: 4.89s	remaining: 5.69s
# 231:	learn: 0.0062315	total: 4.93s	remaining: 5.69s
# 232:	learn: 0.0062315	total: 5.02s	remaining: 5.75s
# 233:	learn: 0.0062314	total: 5.07s	remaining: 5.76s
# 234:	learn: 0.0062314	total: 5.11s	remaining: 5.76s
# 235:	learn: 0.0062310	total: 5.15s	remaining: 5.76s
# 236:	learn: 0.0062310	total: 5.17s	remaining: 5.74s
# 237:	learn: 0.0062302	total: 5.2s	remaining: 5.72s
# 238:	learn: 0.0062302	total: 5.23s	remaining: 5.71s
# 239:	learn: 0.0062301	total: 5.26s	remaining: 5.7s
# 240:	learn: 0.0062301	total: 5.3s	remaining: 5.7s
# 241:	learn: 0.0062300	total: 5.34s	remaining: 5.7s
# 242:	learn: 0.0062300	total: 5.37s	remaining: 5.67s
# 243:	learn: 0.0062096	total: 5.41s	remaining: 5.67s
# 244:	learn: 0.0062095	total: 5.46s	remaining: 5.68s
# 245:	learn: 0.0062095	total: 5.52s	remaining: 5.7s
# 246:	learn: 0.0062095	total: 5.56s	remaining: 5.7s
# 247:	learn: 0.0062093	total: 5.61s	remaining: 5.7s
# 248:	learn: 0.0062093	total: 5.64s	remaining: 5.69s
# 249:	learn: 0.0062072	total: 5.69s	remaining: 5.69s
# 250:	learn: 0.0062072	total: 5.74s	remaining: 5.7s
# 251:	learn: 0.0062072	total: 5.81s	remaining: 5.71s
# 252:	learn: 0.0062071	total: 5.86s	remaining: 5.72s
# 253:	learn: 0.0062070	total: 5.92s	remaining: 5.73s
# 254:	learn: 0.0062069	total: 6s	remaining: 5.76s
# 255:	learn: 0.0062069	total: 6.08s	remaining: 5.8s
# 256:	learn: 0.0062068	total: 6.15s	remaining: 5.82s
# 257:	learn: 0.0062067	total: 6.2s	remaining: 5.82s
# 258:	learn: 0.0062065	total: 6.24s	remaining: 5.81s
# 259:	learn: 0.0062065	total: 6.3s	remaining: 5.81s
# 260:	learn: 0.0062064	total: 6.35s	remaining: 5.81s
# 261:	learn: 0.0062063	total: 6.39s	remaining: 5.8s
# 262:	learn: 0.0062062	total: 6.43s	remaining: 5.79s
# 263:	learn: 0.0062061	total: 6.46s	remaining: 5.78s
# 264:	learn: 0.0062060	total: 6.54s	remaining: 5.8s
# 265:	learn: 0.0062059	total: 6.61s	remaining: 5.81s
# 266:	learn: 0.0062059	total: 6.66s	remaining: 5.81s
# 267:	learn: 0.0062058	total: 6.69s	remaining: 5.79s
# 268:	learn: 0.0062056	total: 6.73s	remaining: 5.78s
# 269:	learn: 0.0061929	total: 6.79s	remaining: 5.79s
# 270:	learn: 0.0060451	total: 6.84s	remaining: 5.78s
# 271:	learn: 0.0059787	total: 6.88s	remaining: 5.77s
# 272:	learn: 0.0059787	total: 6.92s	remaining: 5.76s
# 273:	learn: 0.0059785	total: 6.98s	remaining: 5.76s
# 274:	learn: 0.0059784	total: 7.03s	remaining: 5.75s
# 275:	learn: 0.0059783	total: 7.1s	remaining: 5.76s
# 276:	learn: 0.0059783	total: 7.17s	remaining: 5.77s
# 277:	learn: 0.0059782	total: 7.22s	remaining: 5.77s
# 278:	learn: 0.0059782	total: 7.28s	remaining: 5.77s
# 279:	learn: 0.0059781	total: 7.33s	remaining: 5.76s
# 280:	learn: 0.0059781	total: 7.37s	remaining: 5.74s
# 281:	learn: 0.0059781	total: 7.41s	remaining: 5.73s
# 282:	learn: 0.0059336	total: 7.49s	remaining: 5.74s
# 283:	learn: 0.0058798	total: 7.56s	remaining: 5.75s
# 284:	learn: 0.0058797	total: 7.64s	remaining: 5.76s
# 285:	learn: 0.0058796	total: 7.68s	remaining: 5.75s
# 286:	learn: 0.0058796	total: 7.75s	remaining: 5.75s
# 287:	learn: 0.0058233	total: 7.82s	remaining: 5.76s
# 288:	learn: 0.0058233	total: 7.87s	remaining: 5.75s
# 289:	learn: 0.0057674	total: 7.93s	remaining: 5.75s
# 290:	learn: 0.0057674	total: 8.01s	remaining: 5.75s
# 291:	learn: 0.0057674	total: 8.09s	remaining: 5.76s
# 292:	learn: 0.0057029	total: 8.15s	remaining: 5.76s
# 293:	learn: 0.0057029	total: 8.22s	remaining: 5.76s
# 294:	learn: 0.0057028	total: 8.3s	remaining: 5.77s
# 295:	learn: 0.0056885	total: 8.39s	remaining: 5.78s
# 296:	learn: 0.0055991	total: 8.47s	remaining: 5.79s
# 297:	learn: 0.0055991	total: 8.53s	remaining: 5.78s
# 298:	learn: 0.0055991	total: 8.56s	remaining: 5.76s
# 299:	learn: 0.0055990	total: 8.63s	remaining: 5.75s
# 300:	learn: 0.0055989	total: 8.68s	remaining: 5.74s
# 301:	learn: 0.0055988	total: 8.73s	remaining: 5.73s
# 302:	learn: 0.0055987	total: 8.81s	remaining: 5.73s
# 303:	learn: 0.0055987	total: 8.86s	remaining: 5.71s
# 304:	learn: 0.0055985	total: 8.92s	remaining: 5.7s
# 305:	learn: 0.0055984	total: 8.98s	remaining: 5.7s
# 306:	learn: 0.0055983	total: 9.05s	remaining: 5.69s
# 307:	learn: 0.0055980	total: 9.1s	remaining: 5.67s
# 308:	learn: 0.0055980	total: 9.15s	remaining: 5.66s
# 309:	learn: 0.0055980	total: 9.2s	remaining: 5.64s
# 310:	learn: 0.0055980	total: 9.25s	remaining: 5.62s
# 311:	learn: 0.0055979	total: 9.3s	remaining: 5.6s
# 312:	learn: 0.0055979	total: 9.35s	remaining: 5.59s
# 313:	learn: 0.0055978	total: 9.43s	remaining: 5.59s
# 314:	learn: 0.0055977	total: 9.49s	remaining: 5.58s
# 315:	learn: 0.0055977	total: 9.55s	remaining: 5.56s
# 316:	learn: 0.0055976	total: 9.62s	remaining: 5.55s
# 317:	learn: 0.0055976	total: 9.69s	remaining: 5.54s
# 318:	learn: 0.0055976	total: 9.79s	remaining: 5.56s
# 319:	learn: 0.0055975	total: 9.88s	remaining: 5.56s
# 320:	learn: 0.0055974	total: 10s	remaining: 5.58s
# 321:	learn: 0.0055974	total: 10.1s	remaining: 5.58s
# 322:	learn: 0.0055974	total: 10.2s	remaining: 5.58s
# 323:	learn: 0.0055972	total: 10.3s	remaining: 5.58s
# 324:	learn: 0.0055972	total: 10.4s	remaining: 5.59s
# 325:	learn: 0.0055393	total: 10.5s	remaining: 5.6s
# 326:	learn: 0.0055393	total: 10.6s	remaining: 5.59s
# 327:	learn: 0.0055392	total: 10.6s	remaining: 5.57s
# 328:	learn: 0.0055391	total: 10.7s	remaining: 5.56s
# 329:	learn: 0.0055391	total: 10.8s	remaining: 5.55s
# 330:	learn: 0.0055390	total: 10.9s	remaining: 5.54s
# 331:	learn: 0.0055390	total: 10.9s	remaining: 5.52s
# 332:	learn: 0.0055390	total: 10.9s	remaining: 5.49s
# 333:	learn: 0.0055387	total: 11s	remaining: 5.46s
# 334:	learn: 0.0055386	total: 11s	remaining: 5.44s
# 335:	learn: 0.0055386	total: 11.1s	remaining: 5.43s
# 336:	learn: 0.0055386	total: 11.2s	remaining: 5.41s
# 337:	learn: 0.0054549	total: 11.2s	remaining: 5.39s
# 338:	learn: 0.0054545	total: 11.3s	remaining: 5.37s
# 339:	learn: 0.0054541	total: 11.4s	remaining: 5.36s
# 340:	learn: 0.0053974	total: 11.5s	remaining: 5.34s
# 341:	learn: 0.0053973	total: 11.5s	remaining: 5.32s
# 342:	learn: 0.0053972	total: 11.6s	remaining: 5.3s
# 343:	learn: 0.0053972	total: 11.7s	remaining: 5.28s
# 344:	learn: 0.0053963	total: 11.7s	remaining: 5.27s
# 345:	learn: 0.0053962	total: 11.8s	remaining: 5.24s
# 346:	learn: 0.0053960	total: 11.8s	remaining: 5.22s
# 347:	learn: 0.0053956	total: 11.9s	remaining: 5.2s
# 348:	learn: 0.0053956	total: 12s	remaining: 5.17s
# 349:	learn: 0.0053955	total: 12.1s	remaining: 5.17s
# 350:	learn: 0.0053954	total: 12.1s	remaining: 5.15s
# 351:	learn: 0.0053952	total: 12.2s	remaining: 5.14s
# 352:	learn: 0.0053952	total: 12.3s	remaining: 5.12s
# 353:	learn: 0.0053850	total: 12.4s	remaining: 5.12s
# 354:	learn: 0.0053849	total: 12.5s	remaining: 5.1s
# 355:	learn: 0.0053149	total: 12.6s	remaining: 5.08s
# 356:	learn: 0.0053144	total: 12.6s	remaining: 5.06s
# 357:	learn: 0.0053141	total: 12.7s	remaining: 5.03s
# 358:	learn: 0.0053141	total: 12.8s	remaining: 5.01s
# 359:	learn: 0.0053140	total: 12.8s	remaining: 4.98s
# 360:	learn: 0.0053138	total: 12.9s	remaining: 4.95s
# 361:	learn: 0.0052641	total: 12.9s	remaining: 4.92s
# 362:	learn: 0.0051826	total: 13s	remaining: 4.9s
# 363:	learn: 0.0051825	total: 13s	remaining: 4.86s
# 364:	learn: 0.0051824	total: 13s	remaining: 4.82s
# 365:	learn: 0.0051423	total: 13.1s	remaining: 4.78s
# 366:	learn: 0.0051422	total: 13.1s	remaining: 4.75s
# 367:	learn: 0.0050691	total: 13.1s	remaining: 4.72s
# 368:	learn: 0.0050691	total: 13.2s	remaining: 4.68s
# 369:	learn: 0.0050690	total: 13.2s	remaining: 4.64s
# 370:	learn: 0.0049899	total: 13.3s	remaining: 4.61s
# 371:	learn: 0.0049580	total: 13.3s	remaining: 4.57s
# 372:	learn: 0.0049580	total: 13.3s	remaining: 4.53s
# 373:	learn: 0.0049580	total: 13.3s	remaining: 4.49s
# 374:	learn: 0.0049580	total: 13.4s	remaining: 4.45s
# 375:	learn: 0.0049579	total: 13.4s	remaining: 4.41s
# 376:	learn: 0.0048519	total: 13.4s	remaining: 4.38s
# 377:	learn: 0.0048518	total: 13.5s	remaining: 4.35s
# 378:	learn: 0.0048517	total: 13.5s	remaining: 4.31s
# 379:	learn: 0.0048516	total: 13.5s	remaining: 4.28s
# 380:	learn: 0.0048514	total: 13.6s	remaining: 4.24s
# 381:	learn: 0.0048514	total: 13.6s	remaining: 4.21s
# 382:	learn: 0.0048510	total: 13.7s	remaining: 4.18s
# 383:	learn: 0.0048509	total: 13.7s	remaining: 4.15s
# 384:	learn: 0.0048508	total: 13.8s	remaining: 4.11s
# 385:	learn: 0.0047710	total: 13.8s	remaining: 4.07s
# 386:	learn: 0.0047039	total: 13.8s	remaining: 4.03s
# 387:	learn: 0.0047038	total: 13.8s	remaining: 3.99s
# 388:	learn: 0.0047038	total: 13.9s	remaining: 3.96s
# 389:	learn: 0.0047038	total: 13.9s	remaining: 3.92s
# 390:	learn: 0.0047037	total: 13.9s	remaining: 3.89s
# 391:	learn: 0.0047037	total: 14s	remaining: 3.85s
# 392:	learn: 0.0047036	total: 14s	remaining: 3.81s
# 393:	learn: 0.0047036	total: 14s	remaining: 3.77s
# 394:	learn: 0.0047035	total: 14.1s	remaining: 3.74s
# 395:	learn: 0.0047034	total: 14.1s	remaining: 3.7s
# 396:	learn: 0.0047033	total: 14.1s	remaining: 3.66s
# 397:	learn: 0.0047033	total: 14.2s	remaining: 3.63s
# 398:	learn: 0.0047032	total: 14.2s	remaining: 3.6s
# 399:	learn: 0.0047032	total: 14.3s	remaining: 3.56s
# 400:	learn: 0.0047031	total: 14.3s	remaining: 3.53s
# 401:	learn: 0.0047030	total: 14.3s	remaining: 3.49s
# 402:	learn: 0.0047030	total: 14.3s	remaining: 3.45s
# 403:	learn: 0.0047029	total: 14.4s	remaining: 3.42s
# 404:	learn: 0.0047029	total: 14.4s	remaining: 3.39s
# 405:	learn: 0.0047028	total: 14.5s	remaining: 3.35s
# 406:	learn: 0.0047028	total: 14.5s	remaining: 3.32s
# 407:	learn: 0.0047028	total: 14.6s	remaining: 3.29s
# 408:	learn: 0.0047027	total: 14.6s	remaining: 3.25s
# 409:	learn: 0.0047027	total: 14.6s	remaining: 3.21s
# 410:	learn: 0.0046491	total: 14.7s	remaining: 3.18s
# 411:	learn: 0.0046487	total: 14.7s	remaining: 3.15s
# 412:	learn: 0.0046487	total: 14.8s	remaining: 3.11s
# 413:	learn: 0.0046487	total: 14.8s	remaining: 3.07s
# 414:	learn: 0.0046486	total: 14.8s	remaining: 3.04s
# 415:	learn: 0.0046485	total: 14.9s	remaining: 3s
# 416:	learn: 0.0046485	total: 14.9s	remaining: 2.96s
# 417:	learn: 0.0046484	total: 14.9s	remaining: 2.92s
# 418:	learn: 0.0046484	total: 14.9s	remaining: 2.88s
# 419:	learn: 0.0046484	total: 15s	remaining: 2.85s
# 420:	learn: 0.0046482	total: 15s	remaining: 2.81s
# 421:	learn: 0.0046482	total: 15s	remaining: 2.78s
# 422:	learn: 0.0046482	total: 15.1s	remaining: 2.74s
# 423:	learn: 0.0046482	total: 15.1s	remaining: 2.7s
# 424:	learn: 0.0046480	total: 15.1s	remaining: 2.67s
# 425:	learn: 0.0046478	total: 15.1s	remaining: 2.63s
# 426:	learn: 0.0046477	total: 15.2s	remaining: 2.59s
# 427:	learn: 0.0046477	total: 15.2s	remaining: 2.56s
# 428:	learn: 0.0046477	total: 15.2s	remaining: 2.52s
# 429:	learn: 0.0046475	total: 15.3s	remaining: 2.48s
# 430:	learn: 0.0046475	total: 15.3s	remaining: 2.45s
# 431:	learn: 0.0046475	total: 15.3s	remaining: 2.41s
# 432:	learn: 0.0046475	total: 15.4s	remaining: 2.38s
# 433:	learn: 0.0046474	total: 15.4s	remaining: 2.34s
# 434:	learn: 0.0046474	total: 15.4s	remaining: 2.31s
# 435:	learn: 0.0046473	total: 15.5s	remaining: 2.27s
# 436:	learn: 0.0046472	total: 15.5s	remaining: 2.23s
# 437:	learn: 0.0046472	total: 15.5s	remaining: 2.2s
# 438:	learn: 0.0046470	total: 15.6s	remaining: 2.16s
# 439:	learn: 0.0046469	total: 15.6s	remaining: 2.12s
# 440:	learn: 0.0046469	total: 15.6s	remaining: 2.09s
# 441:	learn: 0.0046468	total: 15.6s	remaining: 2.05s
# 442:	learn: 0.0046468	total: 15.7s	remaining: 2.02s
# 443:	learn: 0.0046468	total: 15.7s	remaining: 1.98s
# 444:	learn: 0.0046468	total: 15.8s	remaining: 1.95s
# 445:	learn: 0.0046468	total: 15.8s	remaining: 1.91s
# 446:	learn: 0.0046467	total: 15.9s	remaining: 1.88s
# 447:	learn: 0.0046467	total: 15.9s	remaining: 1.84s
# 448:	learn: 0.0046465	total: 15.9s	remaining: 1.81s
# 449:	learn: 0.0046465	total: 15.9s	remaining: 1.77s
# 450:	learn: 0.0046464	total: 16s	remaining: 1.74s
# 451:	learn: 0.0046464	total: 16s	remaining: 1.7s
# 452:	learn: 0.0046464	total: 16.1s	remaining: 1.67s
# 453:	learn: 0.0046464	total: 16.1s	remaining: 1.63s
# 454:	learn: 0.0046463	total: 16.1s	remaining: 1.59s
# 455:	learn: 0.0046463	total: 16.2s	remaining: 1.56s
# 456:	learn: 0.0046463	total: 16.2s	remaining: 1.52s
# 457:	learn: 0.0046462	total: 16.3s	remaining: 1.49s
# 458:	learn: 0.0046461	total: 16.3s	remaining: 1.46s
# 459:	learn: 0.0046461	total: 16.4s	remaining: 1.42s
# 460:	learn: 0.0046460	total: 16.4s	remaining: 1.39s
# 461:	learn: 0.0046459	total: 16.4s	remaining: 1.35s
# 462:	learn: 0.0046459	total: 16.4s	remaining: 1.31s
# 463:	learn: 0.0046458	total: 16.5s	remaining: 1.28s
# 464:	learn: 0.0046458	total: 16.5s	remaining: 1.24s
# 465:	learn: 0.0046456	total: 16.6s	remaining: 1.21s
# 466:	learn: 0.0046456	total: 16.6s	remaining: 1.17s
# 467:	learn: 0.0046239	total: 16.7s	remaining: 1.14s
# 468:	learn: 0.0046238	total: 16.8s	remaining: 1.11s
# 469:	learn: 0.0046236	total: 16.9s	remaining: 1.07s
# 470:	learn: 0.0046235	total: 16.9s	remaining: 1.04s
# 471:	learn: 0.0046235	total: 16.9s	remaining: 1s
# 472:	learn: 0.0046231	total: 17s	remaining: 968ms
# 473:	learn: 0.0046229	total: 17s	remaining: 932ms
# 474:	learn: 0.0046229	total: 17s	remaining: 895ms
# 475:	learn: 0.0046228	total: 17s	remaining: 859ms
# 476:	learn: 0.0046227	total: 17.1s	remaining: 824ms
# 477:	learn: 0.0046014	total: 17.1s	remaining: 788ms
# 478:	learn: 0.0046012	total: 17.2s	remaining: 754ms
# 479:	learn: 0.0046012	total: 17.2s	remaining: 718ms
# 480:	learn: 0.0046012	total: 17.3s	remaining: 683ms
# 481:	learn: 0.0046012	total: 17.3s	remaining: 647ms
# 482:	learn: 0.0046012	total: 17.4s	remaining: 612ms
# 483:	learn: 0.0046010	total: 17.4s	remaining: 576ms
# 484:	learn: 0.0046009	total: 17.5s	remaining: 541ms
# 485:	learn: 0.0046008	total: 17.5s	remaining: 504ms
# 486:	learn: 0.0046008	total: 17.5s	remaining: 468ms
# 487:	learn: 0.0046008	total: 17.6s	remaining: 433ms
# 488:	learn: 0.0046007	total: 17.7s	remaining: 397ms
# 489:	learn: 0.0046007	total: 17.7s	remaining: 361ms
# 490:	learn: 0.0046007	total: 17.7s	remaining: 325ms
# 491:	learn: 0.0046007	total: 17.8s	remaining: 289ms
# 492:	learn: 0.0046007	total: 17.8s	remaining: 253ms
# 493:	learn: 0.0046005	total: 17.9s	remaining: 217ms
# 494:	learn: 0.0046005	total: 17.9s	remaining: 181ms
# 495:	learn: 0.0046005	total: 17.9s	remaining: 145ms
# 496:	learn: 0.0046005	total: 18s	remaining: 108ms
# 497:	learn: 0.0046005	total: 18s	remaining: 72.2ms
# 498:	learn: 0.0046005	total: 18s	remaining: 36.1ms
# 499:	learn: 0.0046005	total: 18.1s	remaining: 0us
#  Fold 횟수 : 2
# 0:	learn: 0.3789670	total: 78.8ms	remaining: 39.3s
# 1:	learn: 0.2703372	total: 148ms	remaining: 36.9s
# 2:	learn: 0.2119685	total: 236ms	remaining: 39.1s
# 3:	learn: 0.1887897	total: 314ms	remaining: 38.9s
# 4:	learn: 0.1572675	total: 375ms	remaining: 37.1s
# 5:	learn: 0.1445962	total: 447ms	remaining: 36.8s
# 6:	learn: 0.1349070	total: 520ms	remaining: 36.6s
# 7:	learn: 0.1252837	total: 581ms	remaining: 35.7s
# 8:	learn: 0.1212082	total: 661ms	remaining: 36s
# 9:	learn: 0.1159171	total: 735ms	remaining: 36s
# 10:	learn: 0.1091640	total: 793ms	remaining: 35.3s
# 11:	learn: 0.1048930	total: 862ms	remaining: 35s
# 12:	learn: 0.0996600	total: 924ms	remaining: 34.6s
# 13:	learn: 0.0969147	total: 1.03s	remaining: 35.6s
# 14:	learn: 0.0934475	total: 1.09s	remaining: 35.2s
# 15:	learn: 0.0908678	total: 1.17s	remaining: 35.4s
# 16:	learn: 0.0882235	total: 1.25s	remaining: 35.5s
# 17:	learn: 0.0858320	total: 1.32s	remaining: 35.3s
# 18:	learn: 0.0832859	total: 1.39s	remaining: 35.3s
# 19:	learn: 0.0804364	total: 1.41s	remaining: 34s
# 20:	learn: 0.0774770	total: 1.43s	remaining: 32.7s
# 21:	learn: 0.0759905	total: 1.45s	remaining: 31.6s
# 22:	learn: 0.0734508	total: 1.48s	remaining: 30.7s
# 23:	learn: 0.0721281	total: 1.5s	remaining: 29.7s
# 24:	learn: 0.0701530	total: 1.52s	remaining: 28.8s
# 25:	learn: 0.0683886	total: 1.54s	remaining: 28s
# 26:	learn: 0.0647872	total: 1.56s	remaining: 27.3s
# 27:	learn: 0.0636705	total: 1.58s	remaining: 26.6s
# 28:	learn: 0.0616066	total: 1.6s	remaining: 26s
# 29:	learn: 0.0610856	total: 1.62s	remaining: 25.4s
# 30:	learn: 0.0591383	total: 1.64s	remaining: 24.9s
# 31:	learn: 0.0579025	total: 1.66s	remaining: 24.3s
# 32:	learn: 0.0561706	total: 1.68s	remaining: 23.8s
# 33:	learn: 0.0550817	total: 1.7s	remaining: 23.3s
# 34:	learn: 0.0536261	total: 1.72s	remaining: 22.9s
# 35:	learn: 0.0531263	total: 1.74s	remaining: 22.4s
# 36:	learn: 0.0519765	total: 1.76s	remaining: 22.1s
# 37:	learn: 0.0516085	total: 1.78s	remaining: 21.7s
# 38:	learn: 0.0506837	total: 1.81s	remaining: 21.4s
# 39:	learn: 0.0497069	total: 1.83s	remaining: 21s
# 40:	learn: 0.0484294	total: 1.85s	remaining: 20.7s
# 41:	learn: 0.0482380	total: 1.87s	remaining: 20.4s
# 42:	learn: 0.0470636	total: 1.89s	remaining: 20.1s
# 43:	learn: 0.0456303	total: 1.91s	remaining: 19.8s
# 44:	learn: 0.0455538	total: 1.93s	remaining: 19.5s
# 45:	learn: 0.0442616	total: 1.97s	remaining: 19.5s
# 46:	learn: 0.0431635	total: 2s	remaining: 19.2s
# 47:	learn: 0.0426614	total: 2.02s	remaining: 19s
# 48:	learn: 0.0420036	total: 2.04s	remaining: 18.8s
# 49:	learn: 0.0416248	total: 2.06s	remaining: 18.5s
# 50:	learn: 0.0403616	total: 2.08s	remaining: 18.3s
# 51:	learn: 0.0396562	total: 2.1s	remaining: 18.1s
# 52:	learn: 0.0392644	total: 2.12s	remaining: 17.9s
# 53:	learn: 0.0383528	total: 2.15s	remaining: 17.7s
# 54:	learn: 0.0374351	total: 2.17s	remaining: 17.5s
# 55:	learn: 0.0361533	total: 2.19s	remaining: 17.3s
# 56:	learn: 0.0351953	total: 2.21s	remaining: 17.1s
# 57:	learn: 0.0347844	total: 2.24s	remaining: 17s
# 58:	learn: 0.0343759	total: 2.26s	remaining: 16.9s
# 59:	learn: 0.0334827	total: 2.28s	remaining: 16.7s
# 60:	learn: 0.0330044	total: 2.3s	remaining: 16.5s
# 61:	learn: 0.0319143	total: 2.32s	remaining: 16.4s
# 62:	learn: 0.0313442	total: 2.34s	remaining: 16.2s
# 63:	learn: 0.0310593	total: 2.36s	remaining: 16.1s
# 64:	learn: 0.0306396	total: 2.38s	remaining: 15.9s
# 65:	learn: 0.0304108	total: 2.4s	remaining: 15.8s
# 66:	learn: 0.0300449	total: 2.42s	remaining: 15.6s
# 67:	learn: 0.0294737	total: 2.44s	remaining: 15.5s
# 68:	learn: 0.0285723	total: 2.46s	remaining: 15.4s
# 69:	learn: 0.0282940	total: 2.49s	remaining: 15.3s
# 70:	learn: 0.0274029	total: 2.51s	remaining: 15.1s
# 71:	learn: 0.0273845	total: 2.52s	remaining: 15s
# 72:	learn: 0.0271873	total: 2.54s	remaining: 14.9s
# 73:	learn: 0.0266479	total: 2.57s	remaining: 14.8s
# 74:	learn: 0.0264162	total: 2.59s	remaining: 14.7s
# 75:	learn: 0.0260171	total: 2.61s	remaining: 14.6s
# 76:	learn: 0.0259471	total: 2.63s	remaining: 14.5s
# 77:	learn: 0.0258920	total: 2.65s	remaining: 14.4s
# 78:	learn: 0.0258425	total: 2.67s	remaining: 14.2s
# 79:	learn: 0.0254448	total: 2.72s	remaining: 14.3s
# 80:	learn: 0.0251522	total: 2.74s	remaining: 14.2s
# 81:	learn: 0.0250046	total: 2.76s	remaining: 14.1s
# 82:	learn: 0.0244915	total: 2.78s	remaining: 14s
# 83:	learn: 0.0238600	total: 2.8s	remaining: 13.9s
# 84:	learn: 0.0233851	total: 2.83s	remaining: 13.8s
# 85:	learn: 0.0229813	total: 2.85s	remaining: 13.7s
# 86:	learn: 0.0223278	total: 2.88s	remaining: 13.7s
# 87:	learn: 0.0218271	total: 2.9s	remaining: 13.6s
# 88:	learn: 0.0214687	total: 2.92s	remaining: 13.5s
# 89:	learn: 0.0214356	total: 2.94s	remaining: 13.4s
# 90:	learn: 0.0211022	total: 2.97s	remaining: 13.4s
# 91:	learn: 0.0208556	total: 2.99s	remaining: 13.3s
# 92:	learn: 0.0206540	total: 3.02s	remaining: 13.2s
# 93:	learn: 0.0204970	total: 3.04s	remaining: 13.1s
# 94:	learn: 0.0200726	total: 3.06s	remaining: 13s
# 95:	learn: 0.0197251	total: 3.08s	remaining: 13s
# 96:	learn: 0.0196616	total: 3.1s	remaining: 12.9s
# 97:	learn: 0.0194426	total: 3.12s	remaining: 12.8s
# 98:	learn: 0.0192675	total: 3.14s	remaining: 12.7s
# 99:	learn: 0.0189156	total: 3.16s	remaining: 12.6s
# 100:	learn: 0.0186779	total: 3.19s	remaining: 12.6s
# 101:	learn: 0.0186347	total: 3.21s	remaining: 12.5s
# 102:	learn: 0.0185981	total: 3.23s	remaining: 12.4s
# 103:	learn: 0.0185195	total: 3.25s	remaining: 12.4s
# 104:	learn: 0.0183060	total: 3.27s	remaining: 12.3s
# 105:	learn: 0.0179272	total: 3.3s	remaining: 12.3s
# 106:	learn: 0.0179139	total: 3.32s	remaining: 12.2s
# 107:	learn: 0.0176034	total: 3.34s	remaining: 12.1s
# 108:	learn: 0.0171681	total: 3.36s	remaining: 12.1s
# 109:	learn: 0.0171288	total: 3.38s	remaining: 12s
# 110:	learn: 0.0167896	total: 3.4s	remaining: 11.9s
# 111:	learn: 0.0164383	total: 3.42s	remaining: 11.8s
# 112:	learn: 0.0164186	total: 3.44s	remaining: 11.8s
# 113:	learn: 0.0164061	total: 3.46s	remaining: 11.7s
# 114:	learn: 0.0163502	total: 3.48s	remaining: 11.6s
# 115:	learn: 0.0160769	total: 3.5s	remaining: 11.6s
# 116:	learn: 0.0159619	total: 3.52s	remaining: 11.5s
# 117:	learn: 0.0157018	total: 3.54s	remaining: 11.5s
# 118:	learn: 0.0154925	total: 3.56s	remaining: 11.4s
# 119:	learn: 0.0153235	total: 3.59s	remaining: 11.4s
# 120:	learn: 0.0152436	total: 3.61s	remaining: 11.3s
# 121:	learn: 0.0152240	total: 3.63s	remaining: 11.2s
# 122:	learn: 0.0150742	total: 3.65s	remaining: 11.2s
# 123:	learn: 0.0149438	total: 3.66s	remaining: 11.1s
# 124:	learn: 0.0148444	total: 3.68s	remaining: 11.1s
# 125:	learn: 0.0146081	total: 3.71s	remaining: 11s
# 126:	learn: 0.0144505	total: 3.73s	remaining: 10.9s
# 127:	learn: 0.0141652	total: 3.75s	remaining: 10.9s
# 128:	learn: 0.0140575	total: 3.77s	remaining: 10.8s
# 129:	learn: 0.0137387	total: 3.79s	remaining: 10.8s
# 130:	learn: 0.0136751	total: 3.81s	remaining: 10.7s
# 131:	learn: 0.0134919	total: 3.83s	remaining: 10.7s
# 132:	learn: 0.0131077	total: 3.85s	remaining: 10.6s
# 133:	learn: 0.0130677	total: 3.87s	remaining: 10.6s
# 134:	learn: 0.0129809	total: 3.89s	remaining: 10.5s
# 135:	learn: 0.0129806	total: 3.91s	remaining: 10.5s
# 136:	learn: 0.0129163	total: 3.93s	remaining: 10.4s
# 137:	learn: 0.0128235	total: 3.95s	remaining: 10.4s
# 138:	learn: 0.0128045	total: 3.99s	remaining: 10.4s
# 139:	learn: 0.0125558	total: 4.01s	remaining: 10.3s
# 140:	learn: 0.0123295	total: 4.03s	remaining: 10.3s
# 141:	learn: 0.0121681	total: 4.05s	remaining: 10.2s
# 142:	learn: 0.0120370	total: 4.07s	remaining: 10.2s
# 143:	learn: 0.0120063	total: 4.08s	remaining: 10.1s
# 144:	learn: 0.0118450	total: 4.11s	remaining: 10.1s
# 145:	learn: 0.0117344	total: 4.13s	remaining: 10s
# 146:	learn: 0.0114896	total: 4.15s	remaining: 9.96s
# 147:	learn: 0.0113960	total: 4.17s	remaining: 9.91s
# 148:	learn: 0.0113432	total: 4.2s	remaining: 9.9s
# 149:	learn: 0.0111065	total: 4.22s	remaining: 9.85s
# 150:	learn: 0.0109773	total: 4.24s	remaining: 9.81s
# 151:	learn: 0.0108150	total: 4.26s	remaining: 9.76s
# 152:	learn: 0.0106652	total: 4.28s	remaining: 9.72s
# 153:	learn: 0.0105879	total: 4.3s	remaining: 9.67s
# 154:	learn: 0.0105602	total: 4.33s	remaining: 9.63s
# 155:	learn: 0.0103257	total: 4.35s	remaining: 9.59s
# 156:	learn: 0.0102167	total: 4.37s	remaining: 9.55s
# 157:	learn: 0.0102165	total: 4.39s	remaining: 9.5s
# 158:	learn: 0.0099665	total: 4.41s	remaining: 9.46s
# 159:	learn: 0.0097776	total: 4.43s	remaining: 9.42s
# 160:	learn: 0.0096471	total: 4.47s	remaining: 9.41s
# 161:	learn: 0.0094876	total: 4.5s	remaining: 9.39s
# 162:	learn: 0.0094876	total: 4.54s	remaining: 9.39s
# 163:	learn: 0.0094876	total: 4.57s	remaining: 9.35s
# 164:	learn: 0.0094875	total: 4.59s	remaining: 9.32s
# 165:	learn: 0.0094874	total: 4.62s	remaining: 9.29s
# 166:	learn: 0.0094871	total: 4.66s	remaining: 9.3s
# 167:	learn: 0.0094871	total: 4.7s	remaining: 9.3s
# 168:	learn: 0.0094870	total: 4.74s	remaining: 9.28s
# 169:	learn: 0.0094868	total: 4.77s	remaining: 9.25s
# 170:	learn: 0.0094867	total: 4.8s	remaining: 9.24s
# 171:	learn: 0.0093651	total: 4.85s	remaining: 9.25s
# 172:	learn: 0.0093422	total: 4.89s	remaining: 9.24s
# 173:	learn: 0.0092293	total: 4.93s	remaining: 9.24s
# 174:	learn: 0.0091117	total: 4.99s	remaining: 9.26s
# 175:	learn: 0.0090315	total: 5.04s	remaining: 9.27s
# 176:	learn: 0.0090141	total: 5.08s	remaining: 9.27s
# 177:	learn: 0.0090141	total: 5.12s	remaining: 9.26s
# 178:	learn: 0.0088662	total: 5.18s	remaining: 9.28s
# 179:	learn: 0.0087673	total: 5.23s	remaining: 9.3s
# 180:	learn: 0.0087526	total: 5.28s	remaining: 9.31s
# 181:	learn: 0.0086620	total: 5.32s	remaining: 9.3s
# 182:	learn: 0.0085683	total: 5.36s	remaining: 9.29s
# 183:	learn: 0.0085682	total: 5.4s	remaining: 9.28s
# 184:	learn: 0.0085681	total: 5.44s	remaining: 9.26s
# 185:	learn: 0.0084677	total: 5.48s	remaining: 9.25s
# 186:	learn: 0.0083647	total: 5.53s	remaining: 9.25s
# 187:	learn: 0.0083647	total: 5.56s	remaining: 9.23s
# 188:	learn: 0.0083645	total: 5.61s	remaining: 9.23s
# 189:	learn: 0.0083642	total: 5.66s	remaining: 9.23s
# 190:	learn: 0.0083641	total: 5.7s	remaining: 9.22s
# 191:	learn: 0.0083517	total: 5.73s	remaining: 9.19s
# 192:	learn: 0.0083517	total: 5.77s	remaining: 9.17s
# 193:	learn: 0.0083511	total: 5.8s	remaining: 9.16s
# 194:	learn: 0.0083511	total: 5.85s	remaining: 9.15s
# 195:	learn: 0.0083510	total: 5.88s	remaining: 9.12s
# 196:	learn: 0.0083509	total: 5.92s	remaining: 9.11s
# 197:	learn: 0.0083507	total: 5.96s	remaining: 9.09s
# 198:	learn: 0.0082886	total: 6s	remaining: 9.08s
# 199:	learn: 0.0082885	total: 6.05s	remaining: 9.08s
# 200:	learn: 0.0082885	total: 6.1s	remaining: 9.07s
# 201:	learn: 0.0082883	total: 6.13s	remaining: 9.05s
# 202:	learn: 0.0082881	total: 6.17s	remaining: 9.03s
# 203:	learn: 0.0082879	total: 6.21s	remaining: 9.01s
# 204:	learn: 0.0082877	total: 6.25s	remaining: 8.99s
# 205:	learn: 0.0082875	total: 6.29s	remaining: 8.98s
# 206:	learn: 0.0082873	total: 6.32s	remaining: 8.95s
# 207:	learn: 0.0082873	total: 6.34s	remaining: 8.9s
# 208:	learn: 0.0082870	total: 6.38s	remaining: 8.88s
# 209:	learn: 0.0082870	total: 6.42s	remaining: 8.86s
# 210:	learn: 0.0082870	total: 6.46s	remaining: 8.84s
# 211:	learn: 0.0082422	total: 6.5s	remaining: 8.83s
# 212:	learn: 0.0081390	total: 6.55s	remaining: 8.82s
# 213:	learn: 0.0081389	total: 6.59s	remaining: 8.8s
# 214:	learn: 0.0081147	total: 6.63s	remaining: 8.79s
# 215:	learn: 0.0081146	total: 6.67s	remaining: 8.77s
# 216:	learn: 0.0079981	total: 6.7s	remaining: 8.73s
# 217:	learn: 0.0079981	total: 6.73s	remaining: 8.71s
# 218:	learn: 0.0079975	total: 6.77s	remaining: 8.69s
# 219:	learn: 0.0079841	total: 6.81s	remaining: 8.67s
# 220:	learn: 0.0079249	total: 6.85s	remaining: 8.65s
# 221:	learn: 0.0077869	total: 6.9s	remaining: 8.64s
# 222:	learn: 0.0077869	total: 6.94s	remaining: 8.62s
# 223:	learn: 0.0077010	total: 6.99s	remaining: 8.61s
# 224:	learn: 0.0077009	total: 7.03s	remaining: 8.59s
# 225:	learn: 0.0077007	total: 7.07s	remaining: 8.57s
# 226:	learn: 0.0076888	total: 7.11s	remaining: 8.55s
# 227:	learn: 0.0076283	total: 7.16s	remaining: 8.54s
# 228:	learn: 0.0075353	total: 7.21s	remaining: 8.53s
# 229:	learn: 0.0075351	total: 7.24s	remaining: 8.49s
# 230:	learn: 0.0074385	total: 7.28s	remaining: 8.48s
# 231:	learn: 0.0074383	total: 7.32s	remaining: 8.45s
# 232:	learn: 0.0074383	total: 7.36s	remaining: 8.43s
# 233:	learn: 0.0073562	total: 7.4s	remaining: 8.41s
# 234:	learn: 0.0073561	total: 7.44s	remaining: 8.39s
# 235:	learn: 0.0073217	total: 7.48s	remaining: 8.37s
# 236:	learn: 0.0073214	total: 7.53s	remaining: 8.35s
# 237:	learn: 0.0072316	total: 7.58s	remaining: 8.34s
# 238:	learn: 0.0072315	total: 7.61s	remaining: 8.31s
# 239:	learn: 0.0072315	total: 7.64s	remaining: 8.28s
# 240:	learn: 0.0072315	total: 7.68s	remaining: 8.26s
# 241:	learn: 0.0072314	total: 7.73s	remaining: 8.24s
# 242:	learn: 0.0072313	total: 7.77s	remaining: 8.21s
# 243:	learn: 0.0072312	total: 7.81s	remaining: 8.19s
# 244:	learn: 0.0072311	total: 7.85s	remaining: 8.17s
# 245:	learn: 0.0071976	total: 7.88s	remaining: 8.14s
# 246:	learn: 0.0071414	total: 7.91s	remaining: 8.1s
# 247:	learn: 0.0070662	total: 7.95s	remaining: 8.07s
# 248:	learn: 0.0070091	total: 7.99s	remaining: 8.05s
# 249:	learn: 0.0069055	total: 8.04s	remaining: 8.04s
# 250:	learn: 0.0069056	total: 8.07s	remaining: 8.01s
# 251:	learn: 0.0069054	total: 8.13s	remaining: 8s
# 252:	learn: 0.0069054	total: 8.17s	remaining: 7.97s
# 253:	learn: 0.0068512	total: 8.21s	remaining: 7.95s
# 254:	learn: 0.0068369	total: 8.25s	remaining: 7.93s
# 255:	learn: 0.0068024	total: 8.3s	remaining: 7.91s
# 256:	learn: 0.0067761	total: 8.34s	remaining: 7.89s
# 257:	learn: 0.0067760	total: 8.38s	remaining: 7.86s
# 258:	learn: 0.0067225	total: 8.42s	remaining: 7.83s
# 259:	learn: 0.0067224	total: 8.46s	remaining: 7.81s
# 260:	learn: 0.0067224	total: 8.5s	remaining: 7.79s
# 261:	learn: 0.0066714	total: 8.55s	remaining: 7.76s
# 262:	learn: 0.0065750	total: 8.59s	remaining: 7.74s
# 263:	learn: 0.0065750	total: 8.62s	remaining: 7.71s
# 264:	learn: 0.0065750	total: 8.66s	remaining: 7.68s
# 265:	learn: 0.0065749	total: 8.71s	remaining: 7.66s
# 266:	learn: 0.0065748	total: 8.76s	remaining: 7.64s
# 267:	learn: 0.0065748	total: 8.8s	remaining: 7.62s
# 268:	learn: 0.0065282	total: 8.85s	remaining: 7.6s
# 269:	learn: 0.0065281	total: 8.88s	remaining: 7.56s
# 270:	learn: 0.0065280	total: 8.92s	remaining: 7.54s
# 271:	learn: 0.0065280	total: 8.96s	remaining: 7.51s
# 272:	learn: 0.0065206	total: 9s	remaining: 7.48s
# 273:	learn: 0.0065206	total: 9.04s	remaining: 7.45s
# 274:	learn: 0.0065205	total: 9.07s	remaining: 7.42s
# 275:	learn: 0.0065204	total: 9.12s	remaining: 7.4s
# 276:	learn: 0.0065203	total: 9.16s	remaining: 7.38s
# 277:	learn: 0.0065202	total: 9.2s	remaining: 7.35s
# 278:	learn: 0.0065202	total: 9.24s	remaining: 7.32s
# 279:	learn: 0.0065202	total: 9.28s	remaining: 7.29s
# 280:	learn: 0.0065201	total: 9.32s	remaining: 7.26s
# 281:	learn: 0.0065201	total: 9.34s	remaining: 7.22s
# 282:	learn: 0.0065201	total: 9.36s	remaining: 7.17s
# 283:	learn: 0.0065201	total: 9.38s	remaining: 7.13s
# 284:	learn: 0.0065201	total: 9.4s	remaining: 7.09s
# 285:	learn: 0.0065200	total: 9.41s	remaining: 7.04s
# 286:	learn: 0.0065199	total: 9.43s	remaining: 7s
# 287:	learn: 0.0065199	total: 9.45s	remaining: 6.96s
# 288:	learn: 0.0065200	total: 9.47s	remaining: 6.91s
# 289:	learn: 0.0065200	total: 9.49s	remaining: 6.87s
# 290:	learn: 0.0065200	total: 9.5s	remaining: 6.83s
# 291:	learn: 0.0065199	total: 9.52s	remaining: 6.78s
# 292:	learn: 0.0065198	total: 9.54s	remaining: 6.74s
# 293:	learn: 0.0065197	total: 9.56s	remaining: 6.7s
# 294:	learn: 0.0065197	total: 9.58s	remaining: 6.65s
# 295:	learn: 0.0065196	total: 9.6s	remaining: 6.62s
# 296:	learn: 0.0065194	total: 9.62s	remaining: 6.58s
# 297:	learn: 0.0065193	total: 9.64s	remaining: 6.53s
# 298:	learn: 0.0065193	total: 9.66s	remaining: 6.49s
# 299:	learn: 0.0065192	total: 9.67s	remaining: 6.45s
# 300:	learn: 0.0065192	total: 9.69s	remaining: 6.41s
# 301:	learn: 0.0065191	total: 9.71s	remaining: 6.37s
# 302:	learn: 0.0065190	total: 9.73s	remaining: 6.32s
# 303:	learn: 0.0065190	total: 9.75s	remaining: 6.28s
# 304:	learn: 0.0065188	total: 9.77s	remaining: 6.24s
# 305:	learn: 0.0065187	total: 9.79s	remaining: 6.2s
# 306:	learn: 0.0065186	total: 9.81s	remaining: 6.17s
# 307:	learn: 0.0065186	total: 9.82s	remaining: 6.12s
# 308:	learn: 0.0065184	total: 9.84s	remaining: 6.08s
# 309:	learn: 0.0065182	total: 9.86s	remaining: 6.04s
# 310:	learn: 0.0065181	total: 9.88s	remaining: 6s
# 311:	learn: 0.0065181	total: 9.9s	remaining: 5.96s
# 312:	learn: 0.0065180	total: 9.91s	remaining: 5.92s
# 313:	learn: 0.0065179	total: 9.94s	remaining: 5.89s
# 314:	learn: 0.0065176	total: 9.95s	remaining: 5.85s
# 315:	learn: 0.0065175	total: 9.97s	remaining: 5.81s
# 316:	learn: 0.0065174	total: 9.99s	remaining: 5.77s
# 317:	learn: 0.0065173	total: 10s	remaining: 5.73s
# 318:	learn: 0.0065171	total: 10s	remaining: 5.69s
# 319:	learn: 0.0065132	total: 10s	remaining: 5.65s
# 320:	learn: 0.0065131	total: 10.1s	remaining: 5.61s
# 321:	learn: 0.0065130	total: 10.1s	remaining: 5.58s
# 322:	learn: 0.0065130	total: 10.1s	remaining: 5.54s
# 323:	learn: 0.0065129	total: 10.1s	remaining: 5.5s
# 324:	learn: 0.0065129	total: 10.1s	remaining: 5.46s
# 325:	learn: 0.0065127	total: 10.2s	remaining: 5.43s
# 326:	learn: 0.0065127	total: 10.2s	remaining: 5.4s
# 327:	learn: 0.0065127	total: 10.2s	remaining: 5.36s
# 328:	learn: 0.0065126	total: 10.2s	remaining: 5.32s
# 329:	learn: 0.0065125	total: 10.3s	remaining: 5.29s
# 330:	learn: 0.0065125	total: 10.3s	remaining: 5.25s
# 331:	learn: 0.0064977	total: 10.3s	remaining: 5.21s
# 332:	learn: 0.0064977	total: 10.3s	remaining: 5.17s
# 333:	learn: 0.0064975	total: 10.3s	remaining: 5.14s
# 334:	learn: 0.0064974	total: 10.4s	remaining: 5.1s
# 335:	learn: 0.0064972	total: 10.4s	remaining: 5.07s
# 336:	learn: 0.0064972	total: 10.4s	remaining: 5.03s
# 337:	learn: 0.0064971	total: 10.4s	remaining: 4.99s
# 338:	learn: 0.0064971	total: 10.4s	remaining: 4.96s
# 339:	learn: 0.0064971	total: 10.5s	remaining: 4.92s
# 340:	learn: 0.0064971	total: 10.5s	remaining: 4.88s
# 341:	learn: 0.0064969	total: 10.5s	remaining: 4.85s
# 342:	learn: 0.0064969	total: 10.5s	remaining: 4.81s
# 343:	learn: 0.0064969	total: 10.5s	remaining: 4.78s
# 344:	learn: 0.0064968	total: 10.5s	remaining: 4.74s
# 345:	learn: 0.0064968	total: 10.6s	remaining: 4.7s
# 346:	learn: 0.0064967	total: 10.6s	remaining: 4.67s
# 347:	learn: 0.0064966	total: 10.6s	remaining: 4.63s
# 348:	learn: 0.0064966	total: 10.6s	remaining: 4.6s
# 349:	learn: 0.0064966	total: 10.6s	remaining: 4.56s
# 350:	learn: 0.0064965	total: 10.7s	remaining: 4.53s
# 351:	learn: 0.0064964	total: 10.7s	remaining: 4.49s
# 352:	learn: 0.0064963	total: 10.7s	remaining: 4.46s
# 353:	learn: 0.0064962	total: 10.7s	remaining: 4.42s
# 354:	learn: 0.0064961	total: 10.7s	remaining: 4.39s
# 355:	learn: 0.0064961	total: 10.8s	remaining: 4.35s
# 356:	learn: 0.0064961	total: 10.8s	remaining: 4.32s
# 357:	learn: 0.0064959	total: 10.8s	remaining: 4.28s
# 358:	learn: 0.0064958	total: 10.8s	remaining: 4.25s
# 359:	learn: 0.0064957	total: 10.8s	remaining: 4.21s
# 360:	learn: 0.0064956	total: 10.9s	remaining: 4.18s
# 361:	learn: 0.0064956	total: 10.9s	remaining: 4.15s
# 362:	learn: 0.0064955	total: 10.9s	remaining: 4.11s
# 363:	learn: 0.0064950	total: 10.9s	remaining: 4.08s
# 364:	learn: 0.0064949	total: 10.9s	remaining: 4.04s
# 365:	learn: 0.0063933	total: 11s	remaining: 4.01s
# 366:	learn: 0.0063396	total: 11s	remaining: 3.98s
# 367:	learn: 0.0062307	total: 11s	remaining: 3.94s
# 368:	learn: 0.0062306	total: 11s	remaining: 3.91s
# 369:	learn: 0.0061584	total: 11s	remaining: 3.88s
# 370:	learn: 0.0061584	total: 11.1s	remaining: 3.84s
# 371:	learn: 0.0061584	total: 11.1s	remaining: 3.81s
# 372:	learn: 0.0061582	total: 11.1s	remaining: 3.78s
# 373:	learn: 0.0061582	total: 11.1s	remaining: 3.75s
# 374:	learn: 0.0061582	total: 11.1s	remaining: 3.71s
# 375:	learn: 0.0061582	total: 11.2s	remaining: 3.68s
# 376:	learn: 0.0061579	total: 11.2s	remaining: 3.65s
# 377:	learn: 0.0061579	total: 11.2s	remaining: 3.62s
# 378:	learn: 0.0061579	total: 11.2s	remaining: 3.58s
# 379:	learn: 0.0061578	total: 11.2s	remaining: 3.55s
# 380:	learn: 0.0061577	total: 11.3s	remaining: 3.52s
# 381:	learn: 0.0061576	total: 11.3s	remaining: 3.48s
# 382:	learn: 0.0061576	total: 11.3s	remaining: 3.45s
# 383:	learn: 0.0061575	total: 11.3s	remaining: 3.42s
# 384:	learn: 0.0061574	total: 11.3s	remaining: 3.39s
# 385:	learn: 0.0061574	total: 11.4s	remaining: 3.35s
# 386:	learn: 0.0061574	total: 11.4s	remaining: 3.32s
# 387:	learn: 0.0061573	total: 11.4s	remaining: 3.29s
# 388:	learn: 0.0061572	total: 11.4s	remaining: 3.25s
# 389:	learn: 0.0061571	total: 11.4s	remaining: 3.22s
# 390:	learn: 0.0061570	total: 11.4s	remaining: 3.19s
# 391:	learn: 0.0061569	total: 11.5s	remaining: 3.16s
# 392:	learn: 0.0061568	total: 11.5s	remaining: 3.13s
# 393:	learn: 0.0061568	total: 11.5s	remaining: 3.1s
# 394:	learn: 0.0061566	total: 11.5s	remaining: 3.06s
# 395:	learn: 0.0060914	total: 11.5s	remaining: 3.03s
# 396:	learn: 0.0060455	total: 11.6s	remaining: 3s
# 397:	learn: 0.0060454	total: 11.6s	remaining: 2.97s
# 398:	learn: 0.0060452	total: 11.6s	remaining: 2.94s
# 399:	learn: 0.0060451	total: 11.6s	remaining: 2.91s
# 400:	learn: 0.0060451	total: 11.6s	remaining: 2.87s
# 401:	learn: 0.0059716	total: 11.7s	remaining: 2.84s
# 402:	learn: 0.0059715	total: 11.7s	remaining: 2.81s
# 403:	learn: 0.0059714	total: 11.7s	remaining: 2.78s
# 404:	learn: 0.0058974	total: 11.7s	remaining: 2.75s
# 405:	learn: 0.0058466	total: 11.7s	remaining: 2.72s
# 406:	learn: 0.0058465	total: 11.8s	remaining: 2.69s
# 407:	learn: 0.0058465	total: 11.8s	remaining: 2.66s
# 408:	learn: 0.0058464	total: 11.8s	remaining: 2.63s
# 409:	learn: 0.0058464	total: 11.8s	remaining: 2.6s
# 410:	learn: 0.0058464	total: 11.8s	remaining: 2.56s
# 411:	learn: 0.0058464	total: 11.9s	remaining: 2.53s
# 412:	learn: 0.0058464	total: 11.9s	remaining: 2.5s
# 413:	learn: 0.0058464	total: 11.9s	remaining: 2.47s
# 414:	learn: 0.0058463	total: 11.9s	remaining: 2.44s
# 415:	learn: 0.0058463	total: 11.9s	remaining: 2.41s
# 416:	learn: 0.0058462	total: 12s	remaining: 2.38s
# 417:	learn: 0.0058462	total: 12s	remaining: 2.35s
# 418:	learn: 0.0058462	total: 12s	remaining: 2.32s
# 419:	learn: 0.0058461	total: 12s	remaining: 2.29s
# 420:	learn: 0.0058460	total: 12s	remaining: 2.25s
# 421:	learn: 0.0058459	total: 12s	remaining: 2.23s
# 422:	learn: 0.0058459	total: 12.1s	remaining: 2.19s
# 423:	learn: 0.0058459	total: 12.1s	remaining: 2.16s
# 424:	learn: 0.0058458	total: 12.1s	remaining: 2.13s
# 425:	learn: 0.0058458	total: 12.1s	remaining: 2.1s
# 426:	learn: 0.0058458	total: 12.1s	remaining: 2.08s
# 427:	learn: 0.0058457	total: 12.2s	remaining: 2.04s
# 428:	learn: 0.0058456	total: 12.2s	remaining: 2.01s
# 429:	learn: 0.0058456	total: 12.2s	remaining: 1.98s
# 430:	learn: 0.0058455	total: 12.2s	remaining: 1.96s
# 431:	learn: 0.0058454	total: 12.2s	remaining: 1.93s
# ...
# 322:	learn: 0.0066577	total: 6.64s	remaining: 3.64s
# 323:	learn: 0.0066575	total: 6.65s	remaining: 3.61s
# 324:	learn: 0.0066575	total: 6.68s	remaining: 3.6s
# 325:	learn: 0.0066575	total: 6.7s	remaining: 3.58s
# 326:	learn: 0.0066575	total: 6.72s	remaining: 3.55s
# 327:	learn: 0.0066574	total: 6.74s	remaining: 3.53s
# 328:	learn: 0.0066574	total: 6.75s	remaining: 3.51s
# 329:	learn: 0.0065775	total: 6.77s	remaining: 3.49s
# 330:	learn: 0.0065551	total: 6.79s	remaining: 3.47s
# 331:	learn: 0.0064965	total: 6.81s	remaining: 3.45s
# 332:	learn: 0.0064752	total: 6.83s	remaining: 3.43s
# 333:	learn: 0.0064751	total: 6.85s	remaining: 3.4s
# 334:	learn: 0.0064751	total: 6.87s	remaining: 3.38s
# 335:	learn: 0.0064751	total: 6.89s	remaining: 3.36s
# 336:	learn: 0.0064751	total: 6.91s	remaining: 3.34s
# 337:	learn: 0.0064749	total: 6.94s	remaining: 3.33s
# 338:	learn: 0.0064749	total: 6.96s	remaining: 3.31s
# 339:	learn: 0.0064748	total: 6.99s	remaining: 3.29s
# 340:	learn: 0.0064748	total: 7s	remaining: 3.27s
# 341:	learn: 0.0064748	total: 7.02s	remaining: 3.24s
# 342:	learn: 0.0064747	total: 7.04s	remaining: 3.22s
# 343:	learn: 0.0064747	total: 7.05s	remaining: 3.2s
# 344:	learn: 0.0064746	total: 7.07s	remaining: 3.18s
# 345:	learn: 0.0064746	total: 7.1s	remaining: 3.16s
# 346:	learn: 0.0064746	total: 7.12s	remaining: 3.14s
# 347:	learn: 0.0064745	total: 7.13s	remaining: 3.12s
# 348:	learn: 0.0064744	total: 7.15s	remaining: 3.09s
# 349:	learn: 0.0064744	total: 7.17s	remaining: 3.07s
# 350:	learn: 0.0064744	total: 7.19s	remaining: 3.05s
# 351:	learn: 0.0064744	total: 7.2s	remaining: 3.03s
# 352:	learn: 0.0064743	total: 7.22s	remaining: 3.01s
# 353:	learn: 0.0064743	total: 7.24s	remaining: 2.99s
# 354:	learn: 0.0064743	total: 7.26s	remaining: 2.96s
# 355:	learn: 0.0064742	total: 7.27s	remaining: 2.94s
# 356:	learn: 0.0064740	total: 7.29s	remaining: 2.92s
# 357:	learn: 0.0064740	total: 7.31s	remaining: 2.9s
# 358:	learn: 0.0064740	total: 7.34s	remaining: 2.88s
# 359:	learn: 0.0064740	total: 7.35s	remaining: 2.86s
# 360:	learn: 0.0064740	total: 7.38s	remaining: 2.84s
# 361:	learn: 0.0064739	total: 7.39s	remaining: 2.82s
# 362:	learn: 0.0064738	total: 7.41s	remaining: 2.8s
# 363:	learn: 0.0064737	total: 7.43s	remaining: 2.77s
# 364:	learn: 0.0064737	total: 7.45s	remaining: 2.75s
# 365:	learn: 0.0064735	total: 7.46s	remaining: 2.73s
# 366:	learn: 0.0064732	total: 7.48s	remaining: 2.71s
# 367:	learn: 0.0064732	total: 7.5s	remaining: 2.69s
# 368:	learn: 0.0064732	total: 7.52s	remaining: 2.67s
# 369:	learn: 0.0064731	total: 7.54s	remaining: 2.65s
# 370:	learn: 0.0064730	total: 7.55s	remaining: 2.63s
# 371:	learn: 0.0064730	total: 7.57s	remaining: 2.61s
# 372:	learn: 0.0063956	total: 7.59s	remaining: 2.58s
# 373:	learn: 0.0063606	total: 7.62s	remaining: 2.56s
# 374:	learn: 0.0063605	total: 7.62s	remaining: 2.54s
# 375:	learn: 0.0063605	total: 7.64s	remaining: 2.52s
# 376:	learn: 0.0062905	total: 7.66s	remaining: 2.5s
# 377:	learn: 0.0062905	total: 7.68s	remaining: 2.48s
# 378:	learn: 0.0062904	total: 7.7s	remaining: 2.46s
# 379:	learn: 0.0062904	total: 7.71s	remaining: 2.44s
# 380:	learn: 0.0062903	total: 7.74s	remaining: 2.42s
# 381:	learn: 0.0062903	total: 7.75s	remaining: 2.39s
# 382:	learn: 0.0062903	total: 7.77s	remaining: 2.37s
# 383:	learn: 0.0062903	total: 7.79s	remaining: 2.35s
# 384:	learn: 0.0062901	total: 7.81s	remaining: 2.33s
# 385:	learn: 0.0062901	total: 7.83s	remaining: 2.31s
# 386:	learn: 0.0062901	total: 7.84s	remaining: 2.29s
# 387:	learn: 0.0062901	total: 7.86s	remaining: 2.27s
# 388:	learn: 0.0062901	total: 7.88s	remaining: 2.25s
# 389:	learn: 0.0062900	total: 7.89s	remaining: 2.23s
# 390:	learn: 0.0062899	total: 7.91s	remaining: 2.21s
# 391:	learn: 0.0062898	total: 7.95s	remaining: 2.19s
# 392:	learn: 0.0062897	total: 7.97s	remaining: 2.17s
# 393:	learn: 0.0062897	total: 7.98s	remaining: 2.15s
# 394:	learn: 0.0062895	total: 8s	remaining: 2.13s
# 395:	learn: 0.0062895	total: 8.02s	remaining: 2.1s
# 396:	learn: 0.0062895	total: 8.04s	remaining: 2.08s
# 397:	learn: 0.0062894	total: 8.05s	remaining: 2.06s
# 398:	learn: 0.0062894	total: 8.07s	remaining: 2.04s
# 399:	learn: 0.0062894	total: 8.09s	remaining: 2.02s
# 400:	learn: 0.0062893	total: 8.11s	remaining: 2s
# 401:	learn: 0.0062892	total: 8.12s	remaining: 1.98s
# 402:	learn: 0.0062839	total: 8.14s	remaining: 1.96s
# 403:	learn: 0.0062839	total: 8.16s	remaining: 1.94s
# 404:	learn: 0.0062839	total: 8.18s	remaining: 1.92s
# 405:	learn: 0.0062584	total: 8.2s	remaining: 1.9s
# 406:	learn: 0.0062027	total: 8.22s	remaining: 1.88s
# 407:	learn: 0.0062027	total: 8.24s	remaining: 1.86s
# 408:	learn: 0.0062026	total: 8.26s	remaining: 1.84s
# 409:	learn: 0.0061680	total: 8.28s	remaining: 1.82s
# 410:	learn: 0.0061676	total: 8.3s	remaining: 1.8s
# 411:	learn: 0.0061675	total: 8.32s	remaining: 1.78s
# 412:	learn: 0.0061675	total: 8.34s	remaining: 1.76s
# 413:	learn: 0.0061675	total: 8.35s	remaining: 1.74s
# 414:	learn: 0.0061285	total: 8.38s	remaining: 1.72s
# 415:	learn: 0.0061284	total: 8.4s	remaining: 1.7s
# 416:	learn: 0.0061284	total: 8.41s	remaining: 1.67s
# 417:	learn: 0.0061283	total: 8.43s	remaining: 1.65s
# 418:	learn: 0.0061283	total: 8.45s	remaining: 1.63s
# 419:	learn: 0.0060827	total: 8.47s	remaining: 1.61s
# 420:	learn: 0.0060826	total: 8.48s	remaining: 1.59s
# 421:	learn: 0.0060399	total: 8.5s	remaining: 1.57s
# 422:	learn: 0.0060195	total: 8.52s	remaining: 1.55s
# 423:	learn: 0.0059574	total: 8.54s	remaining: 1.53s
# 424:	learn: 0.0058994	total: 8.56s	remaining: 1.51s
# 425:	learn: 0.0058761	total: 8.59s	remaining: 1.49s
# 426:	learn: 0.0058761	total: 8.61s	remaining: 1.47s
# 427:	learn: 0.0058638	total: 8.63s	remaining: 1.45s
# 428:	learn: 0.0058639	total: 8.65s	remaining: 1.43s
# 429:	learn: 0.0058638	total: 8.66s	remaining: 1.41s
# 430:	learn: 0.0058638	total: 8.68s	remaining: 1.39s
# 431:	learn: 0.0058637	total: 8.7s	remaining: 1.37s
# 432:	learn: 0.0058637	total: 8.72s	remaining: 1.35s
# 433:	learn: 0.0058635	total: 8.73s	remaining: 1.33s
# 434:	learn: 0.0058634	total: 8.75s	remaining: 1.31s
# 435:	learn: 0.0058633	total: 8.77s	remaining: 1.29s
# 436:	learn: 0.0058632	total: 8.79s	remaining: 1.27s
# 437:	learn: 0.0058631	total: 8.81s	remaining: 1.25s
# 438:	learn: 0.0058139	total: 8.83s	remaining: 1.23s
# 439:	learn: 0.0058139	total: 8.85s	remaining: 1.21s
# 440:	learn: 0.0057669	total: 8.87s	remaining: 1.19s
# 441:	learn: 0.0057668	total: 8.88s	remaining: 1.17s
# 442:	learn: 0.0057666	total: 8.9s	remaining: 1.15s
# 443:	learn: 0.0057661	total: 8.92s	remaining: 1.12s
# 444:	learn: 0.0057579	total: 8.94s	remaining: 1.1s
# 445:	learn: 0.0057578	total: 8.97s	remaining: 1.09s
# 446:	learn: 0.0057559	total: 8.99s	remaining: 1.07s
# 447:	learn: 0.0056835	total: 9.02s	remaining: 1.05s
# 448:	learn: 0.0056832	total: 9.04s	remaining: 1.03s
# 449:	learn: 0.0056135	total: 9.06s	remaining: 1.01s
# 450:	learn: 0.0056134	total: 9.07s	remaining: 986ms
# 451:	learn: 0.0056117	total: 9.09s	remaining: 965ms
# 452:	learn: 0.0055383	total: 9.11s	remaining: 945ms
# 453:	learn: 0.0054874	total: 9.13s	remaining: 925ms
# 454:	learn: 0.0054874	total: 9.15s	remaining: 905ms
# 455:	learn: 0.0054874	total: 9.16s	remaining: 884ms
# 456:	learn: 0.0054873	total: 9.18s	remaining: 864ms
# 457:	learn: 0.0054869	total: 9.2s	remaining: 844ms
# 458:	learn: 0.0054868	total: 9.22s	remaining: 824ms
# 459:	learn: 0.0054869	total: 9.24s	remaining: 804ms
# 460:	learn: 0.0054808	total: 9.27s	remaining: 784ms
# 461:	learn: 0.0054790	total: 9.29s	remaining: 764ms
# 462:	learn: 0.0054790	total: 9.31s	remaining: 744ms
# 463:	learn: 0.0054788	total: 9.33s	remaining: 724ms
# 464:	learn: 0.0054787	total: 9.34s	remaining: 703ms
# 465:	learn: 0.0054787	total: 9.36s	remaining: 683ms
# 466:	learn: 0.0054787	total: 9.38s	remaining: 663ms
# 467:	learn: 0.0054787	total: 9.39s	remaining: 642ms
# 468:	learn: 0.0054787	total: 9.41s	remaining: 622ms
# 469:	learn: 0.0054786	total: 9.44s	remaining: 602ms
# 470:	learn: 0.0054784	total: 9.47s	remaining: 583ms
# 471:	learn: 0.0054783	total: 9.5s	remaining: 563ms
# 472:	learn: 0.0054763	total: 9.53s	remaining: 544ms
# 473:	learn: 0.0054761	total: 9.56s	remaining: 524ms
# 474:	learn: 0.0053996	total: 9.6s	remaining: 505ms
# 475:	learn: 0.0053536	total: 9.62s	remaining: 485ms
# 476:	learn: 0.0053536	total: 9.66s	remaining: 466ms
# 477:	learn: 0.0053536	total: 9.7s	remaining: 447ms
# 478:	learn: 0.0053534	total: 9.73s	remaining: 427ms
# 479:	learn: 0.0053191	total: 9.78s	remaining: 407ms
# 480:	learn: 0.0052703	total: 9.82s	remaining: 388ms
# 481:	learn: 0.0052323	total: 9.86s	remaining: 368ms
# 482:	learn: 0.0052321	total: 9.9s	remaining: 349ms
# 483:	learn: 0.0052320	total: 9.95s	remaining: 329ms
# 484:	learn: 0.0052319	total: 9.99s	remaining: 309ms
# 485:	learn: 0.0052268	total: 10s	remaining: 289ms
# 486:	learn: 0.0052267	total: 10.1s	remaining: 269ms
# 487:	learn: 0.0052265	total: 10.1s	remaining: 249ms
# 488:	learn: 0.0052264	total: 10.2s	remaining: 228ms
# 489:	learn: 0.0052263	total: 10.2s	remaining: 208ms
# 490:	learn: 0.0052262	total: 10.2s	remaining: 188ms
# 491:	learn: 0.0052262	total: 10.3s	remaining: 167ms
# 492:	learn: 0.0052261	total: 10.3s	remaining: 147ms
# 493:	learn: 0.0051896	total: 10.4s	remaining: 126ms
# 494:	learn: 0.0051896	total: 10.4s	remaining: 105ms
# 495:	learn: 0.0051896	total: 10.5s	remaining: 84.3ms
# 496:	learn: 0.0051871	total: 10.5s	remaining: 63.4ms
# 497:	learn: 0.0051870	total: 10.5s	remaining: 42.3ms
# 498:	learn: 0.0051870	total: 10.6s	remaining: 21.2ms
# 499:	learn: 0.0051870	total: 10.6s	remaining: 0us
#  Fold 횟수 : 1
#  Fold 횟수 : 2
#  Fold 횟수 : 3
#  Fold 횟수 : 4
#  Fold 횟수 : 5
#  Fold 횟수 : 1
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 8709, number of negative: 5729
# [LightGBM] [Info] Total Bins 7738
# [LightGBM] [Info] Number of data points in the train set: 14438, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.603200 -> initscore=0.418816
# [LightGBM] [Info] Start training from score 0.418816
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
#  Fold 횟수 : 2
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 8731, number of negative: 5707
# [LightGBM] [Info] Total Bins 7724
# [LightGBM] [Info] Number of data points in the train set: 14438, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.604724 -> initscore=0.425186
# [LightGBM] [Info] Start training from score 0.425186
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
#  Fold 횟수 : 3
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 7826, number of negative: 6612
# [LightGBM] [Info] Total Bins 7688
# [LightGBM] [Info] Number of data points in the train set: 14438, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.542042 -> initscore=0.168565
# [LightGBM] [Info] Start training from score 0.168565
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
#  Fold 횟수 : 4
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 5415, number of negative: 9024
# [LightGBM] [Info] Total Bins 7452
# [LightGBM] [Info] Number of data points in the train set: 14439, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.375026 -> initscore=-0.510715
# [LightGBM] [Info] Start training from score -0.510715
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
#  Fold 횟수 : 5
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 5415, number of negative: 9024
# [LightGBM] [Info] Total Bins 7459
# [LightGBM] [Info] Number of data points in the train set: 14439, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.375026 -> initscore=-0.510715
# [LightGBM] [Info] Start training from score -0.510715
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
# 모든 변수 사용시 f1 : 0.6678 -> 0.6656 (hgb 모델 제거) -> 0.6678 (hgb, rf 모델 제거)
# 변수선택시 : 0.6498 -> 0.6531 (hgb 모델 제거) -> 0.6656 (hgb, rf 모델 제거)
# 최종 메타 모델을 위해 결합
stack_final_x_train = np.concatenate((cat_train, xgb_train,lgb_train), axis = 1) # hgb_train, , rf_train
stack_final_x_test = np.concatenate((cat_test, xgb_test,lgb_test), axis = 1) #  hgb_test, , rf_test

# 최종 메타모델 학습
gbc_final.fit(stack_final_x_train, y_train_over)
stack_final_pred = gbc_final.predict(stack_final_x_test)

print(f"최종 메타모델 f1점수 : {f1_score(val_y, stack_final_pred): .4f}")
# Out:
# 최종 메타모델 f1점수 :  0.6678

# %%
pred_stacking = gbc_final.predict_proba(stack_final_x_train)

# %% [markdown]
# #### [2] Regressor model

# %% [markdown]
# ##### 0) X,y 정의

# %%
X = X_train_over[test_stage_features]
# y = pd.DataFrame(pred_stacking).iloc[:,1]
y = pd.DataFrame(pred_xgb).iloc[:,1]

# %% [markdown]
# ##### 1) Elasticnet Regressor

# %%
from sklearn.linear_model import Lasso,ElasticNet,Ridge
from sklearn.model_selection import GridSearchCV

elasticnet = ElasticNet(random_state = 0)
alphas = np.logspace(-4, 0, 200)
parameters = {'alpha': alphas }

elasticnet_reg = GridSearchCV(elasticnet, parameters, scoring='neg_mean_squared_error',cv=5)
elasticnet_reg.fit(X,y)
print(elasticnet_reg.best_params_)
print(elasticnet_reg.best_score_)
# Out:
# {'alpha': 0.0001}
# -0.2945661897516635

# %%
from sklearn.linear_model import Lasso,ElasticNet,Ridge

ER = ElasticNet(alpha = 0.0001, random_state = 0)
ER.fit(X,y)
# Out:
# ElasticNet(alpha=0.0001, random_state=0)

# %%
pred = ER.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.57 :
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.5362278495695132

# %%
# 변수선택(7개) 분류모델 돌린 데이터 사용
pred = ER.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.57 :
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.5337348312813646

# %% [markdown]
# ##### 2) Huber Regressor

# %%
from sklearn.linear_model import HuberRegressor
huber = HuberRegressor(epsilon= 1.4).fit(X, y)

# %%
pred = huber.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.58  : # 기준 0.63
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.5361213027062658

# %%
# 변수선택 기준
pred = huber.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.58  : # 기준 0.63
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.528514519181545

# %%
pred = huber.predict(test)
for i in range(len(pred)) :
  if pred[i] >= 0.58:
    pred[i] = 1
  else :
    pred[i] = 0

# %%
pred = pred.astype(int)

# %% [markdown]
# ##### 3) XGB Regressor

# %%
from xgboost import XGBRegressor

model_xgb = XGBRegressor(learning_rate= 0.2, max_depth = 16, #0.05, 32
                          n_estimators = 100, random_state = 0)

model_xgb.fit(X,y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=16, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)

# %%
# 543
pred = model_xgb.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.46: #0.5
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.5420821471153612

# %%
pred = model_xgb.predict(test)

# %%
for i in range(len(pred)) :
  if pred[i] >= 0.3:
    pred[i] = 1
  else :
    pred[i] = 0

# %%
pred_test = pred.astype(int)

# %% [markdown]
# ##### 4) Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(max_depth = 16, learning_rate = 0.04, n_estimators = 90, subsample = 0.7, random_state = 0)
gbr.fit(X, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.04, max_depth=16, n_estimators=90,
#                           random_state=0, subsample=0.7)

# %%
# XGB 모델 결과 (0.4 기준)
# 16,0.06,80,0.7 : 0.55668
# 16,0.06,90,0.7 : 0.55793
# 16,0.06,100,0.7 : 0.55546
# 16,0.05,90,0.7 : 0.5591
# 16,0.04,90,0.7 : 0.5596 -> 0.5624 (0.42 기준)
# 16,0.03,90,0.7 : 0.55027
# 18,0.04,90,0.7 : 0.5486
# 14,0.04,90,0.7 : 0.5560

pred = gbr.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.42 :
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.5624011651726735

# %%
pred = gbr.predict(test)

# %%
for i in range(len(pred)) :
  if pred[i] >= 0.42:
    pred[i] = 1
  else :
    pred[i] = 0

# %%
pred_test = pred.astype(int)

# %% [markdown]
# ##### 5) LightGBM Regressor

# %%
import lightgbm as ltb

lgb = ltb.LGBMRegressor(learning_rate = 0.05, max_depth = 16, metric = 'rmse')
lgb.fit(X,y)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002867 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3855
# [LightGBM] [Info] Number of data points in the train set: 18048, number of used features: 18
# [LightGBM] [Info] Start training from score 0.500000
# LGBMRegressor(learning_rate=0.05, max_depth=16, metric='rmse')

# %%
# stacking 버전 (0.05,16,rmse)
pred = lgb.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.33: # lgb -> lgb 에서 가장 좋았던 기준 0.595
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# 0.5673411952332847

# %%
# 0.35 : 0.5605092231748506
# 0.36 :0.5575167077193213
# 0.34 : 0.5592002230578205

pred = lgb.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.36: # lgb -> lgb 에서 가장 좋았던 기준 0.595
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# 0.5575167077193213

# %%
pred = lgb.predict(test)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
for i in range(len(pred)) :
  if pred[i] >= 0.33:
    pred[i] = 1
  else :
    pred[i] = 0

# %%
pred_test = pred.astype(int)

# %% [markdown]
# ##### 6) K Neighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

regressor = KNeighborsRegressor(n_neighbors = 20, weights = "distance")
regressor.fit(X, y)
# Out:
# KNeighborsRegressor(n_neighbors=20, weights='distance')

# %%
# 20, 0.79 : 0.5509905526601195
# 0.8 : 0.5504737386672168
# 0.75 : 0.5466300097303332
pred  = regressor.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.79:
    pred[i] = 1
  else :
    pred[i] = 0

from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.5509905526601195

# %%
pred = regressor.predict(test)

# %%
for i in range(len(pred)) :
  if pred[i] >= 0.79:
    pred[i] = 1
  else :
    pred[i] = 0

# %%
pred_test = pred.astype(int)

# %% [markdown]
# ##### 7) RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=0, max_depth=20, min_samples_leaf=4, min_samples_split=10,n_estimators=110)
rf.fit(X, y)
# Out:
# RandomForestRegressor(max_depth=20, min_samples_leaf=4, min_samples_split=10,
#                       n_estimators=110, random_state=0)

# %%
# XGB score (0.42 기준)
# 20,4,10,110 : 0.550668
# 20,4,10,100 : 0.548910
# 20,4,9,110 : 0.55027
# 20,3,10,110 : 0.5494
# 20,5,10,110 : 0.5460
# 18,4,10,110 : 0.5459
# 22,4,10,110 : 0.5470
# 20,4,10,120 : 0.5415
# 20,4,10,80 : 0.5436

pred = rf.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.42:  #0.42 : 0.5485
    pred[i] = 1
  else :
    pred[i] = 0
from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.5506686717192808

# %%
# CATBOOST score (0.44기준)
# 18,4,10,100 : 0.5503046385530627
# 20,4,10,100 : 0.5548732424299898
# 20,4,10,110 : 0.555846504243899
# 20,4,10,120 : 0.552112609342271

pred = rf.predict(val_X[test_stage_features])
for i in range(len(pred)) :
  if pred[i] >= 0.44:  #0.42 : 0.5485
    pred[i] = 1
  else :
    pred[i] = 0
from sklearn.metrics import f1_score
f1_score(pred, val_y, average = 'macro')
# Out:
# 0.5577470266709132

# %%
pred = rf.predict(test)

# %%
for i in range(len(pred)) :
  if pred[i] >= 0.42:
    pred[i] = 1
  else :
    pred[i] = 0

# %%
pred_test = pred.astype(int)

# %% [markdown]
# ### 6. SUBMISSION

# %% [markdown]
# XGBClassifier 분류모델과 RandomForestRegressor 예측모델을 사용한 결과가 가장 좋은 점수를 내어 최종 모델로 결정

# %%
submit = pd.read_csv('/content/drive/MyDrive/건설기계 오일 상태 분류 경진대회/sample_submission.csv')
submit['Y_LABEL'] = pred_test
submit.head()
# Out:
#           ID  Y_LABEL
# 0  TEST_0000        0
# 1  TEST_0001        0
# 2  TEST_0002        0
# 3  TEST_0003        0
# 4  TEST_0004        1

# %%
len(submit[submit['Y_LABEL']==1])/len(submit)
# Out:
# 0.0880648899188876

# %%
submit.to_csv('./xgb(모든변수_17,1,120)_gbr(0.42기준16,0.04,90,0.7).csv', index=False)
